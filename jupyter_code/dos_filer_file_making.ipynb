# %%
file = open("/content/mixed200222.txt","r")
hmm0 =  16540 * .95
hmm1 = 15731
#hmm1 =  hmm1+(57747-hmm1)*0.44028307596077026*10
 #+(25825-6126)*0.00364125
fileW1 = open("mixed_200"+"_5120_"+".txt","w")
#fileW2 = open("dos1_200.txt","w")  

fileW1.write("No.\t"+"Nodes\t"+"Edges\t"+	"MaximumIndegree\t"+"MinimumIndegree\t")
fileW1.write("MaximumOutdegree\t"+"MinimumOutdegree\t"+"MedianPagerank\t"+"MaximumPagerank\t")
fileW1.write("MininumPagerank\t"+"StdPageRank\t"+"VarPageRank\t"+"State\n")

print((hmm0+hmm1)/512)
attackCounter = 0
attackFree = 0
node =0
counter = 0
while True: 
  
    # Get next line from file 
    line = file.readline() 
    if not line: 
        break

    l = list(line.split())
  
    if l[12] == "0" and counter < 57747 and attackCounter < hmm0 :
      fileW1.write(str(line))
      attackCounter +=1
      node = l[0]
    if l[12] == "1" and counter < 57747 and attackFree < hmm1 :
      fileW1.write(str(line))
      attackFree +=1
      node = l[0]
    counter +=1
    # if l[10] == "0" and attackCounter > hmm0:
    #   fileW1.write(str(line))
    # if l[10] == "1" and attackFree > hmm1:
    #   fileW1.write(str(line))

    



fileW1.close()
file.close()

print(node)
print(attackCounter)
print(attackFree)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5495c26c3ad3> in <module>()
# ----> 1 file = open("/content/mixed200222.txt","r")
#       2 hmm0 =  16540 * .95
#       3 hmm1 = 15731
#       4 #hmm1 =  hmm1+(57747-hmm1)*0.44028307596077026*10
#       5  #+(25825-6126)*0.00364125
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/mixed200222.txt'

# %%
file0 = open("/content/dos0_200.txt","r")
file1 = open("/content/dos1_200 (1).txt","r")

filewtest = open("test_dos.txt","w")
filewtrain = open("train_dos.txt","w") 

h0 = 5120
h1 = 25825
ac = 0
af = 0


while True: 
  
    line = file0.readline() 
    if not line: 
        break

    l = list(line.split())

    if ac >= h0:
      filewtest.write(line)
    ac+=1
while True: 
  
    line = file1.readline() 
    if not line: 
        break

    l = list(line.split())

    if af >= h1:
      filewtest.write(line)
    af+=1
    
print(ac)
print(af)
filewtest.close()
file0.close()
file1.close()
filewtrain.close()
# Out:
# 5675
# 31218

# %%
p is attack probablity
q is attackfree probablity

100 smaples
100 times
-(plogp + qlogq)/(total_samples)

p,q < 0 

p+q = 1


if p == 0
-(qlogq)/(total_samples)

else if q == 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-aac0a3f05cfe> in <module>()
# ----> 1 p is attack
#
# NameError: name 'p' is not defined
