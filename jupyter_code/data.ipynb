# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
/content/drive/My Drive/data_can/Fuzzy_attack_dataset (1).txt

# %%
import pandas as pd

# data = pd.read_csv('/content/drive/My Drive/data_can/Fuzzy_attack_dataset (1).txt')
# data.shape


file1 = open('/content/drive/My Drive/data_can/Attack_free_dataset (1).txt', 'r')
file2 = open('/content/drive/My Drive/data_can/attack_free.txt', 'a')  
count = 0

list1 = []  
dict1 = {}
while True: 
    count += 1
  
    # Get next line from file 
    line = file1.readline() 
  
    # if line is empty 
    # end of file is reached 
    if not line: 
        break

    #print(line)
    name = line[36:45]
    list1.append(line[36:45])
    #print(list1)
    

    
    #print("Line{}: {}".format(count, line[36:45]))
  
file1.close()
print(len(list1))
list_set = set(list1)

for val in list_set:
  print(val + str(list1.count(val)))

print(len(list_set))
