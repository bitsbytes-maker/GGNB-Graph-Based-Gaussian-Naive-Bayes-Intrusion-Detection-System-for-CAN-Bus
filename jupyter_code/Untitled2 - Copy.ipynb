# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

G=nx.DiGraph()

G = nx.DiGraph(nx.path_graph(4))
pr = nx.pagerank(G, alpha=0.9)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = False)
nx.draw_networkx_labels(G, pos, labels = pr)

plt.show()
