# %%
import seaborn as sn
import matplotlib.pyplot as plt
import pandas



# load dataset
dataframe = pandas.read_table('/content/completeallwithNode.txt')

data = dataframe.drop("No.", axis=1)
# data = data.drop("Nodes", axis = 1)
# data = data.drop("Edges", axis = 1)
# data = data.drop("Minimum Indegree", axis=1)
# #data = data.drop("Median PageRank", axis = 1)
#data = data.drop("", axis=1)



#print(data)

# for col in data.columns:
#   print(col)

X = dataframe.values




# split into input (X) and output (Y) variables

l = len(dataframe)

#X = data[0:l,1:]
# Y = dataset[100:200, 1:10]
# print(X)
# print(X.shape)
labels = []
for i in range (0,l):
  if X[i][10] == 'T':
    labels.append(0)
  else:
    labels.append(1)

features = X[0:l,1:10]
print(features)

print(labels.count(0))
print(labels.count(1))



# df = dataframe.corr()

# #print(df)

# corrMatrix = data.corr()
# print(corrMatrix)

# sn.heatmap(corrMatrix, annot=True, fmt = ".1g")
# plt.show()
# may be needed
# inList1 = []
# outList1 = []

# inList0 =[]
# outList0 = []

# inList = dataframe['Maximum Indegree']
# outList = dataframe['Maximum Outdegree']


# for i in range(0,len(labels)):
#   if labels[i] == 1:
#     inList1.append(inList[i])
#     outList1.append(outList[i])
#   else:
#     inList0.append(inList[i])
#     outList0.append(outList[i])
# Out:
# [[24 44 5 ... 0.03688071155039866 0.07360649759034145
#   0.016677714846090454]
#  [24 34 3 ... 0.04253696661055606 0.0882129092099077 0.016522395460077763]
#  [24 36 3 ... 0.04400826005008965 0.06481770478688069
#   0.016405861231623044]
#  ...
#  [42 242 20 ... 0.01962590798163142 0.0724726846867403
#   0.004699352964786049]
#  [44 241 20 ... 0.02058400848392282 0.07247380150399091
#   0.005531143028168605]
#  [42 230 22 ... 0.0221067406930489 0.0825651064928123
#   0.004773152146913031]]
# 54995
# 24859

# %%
# Out:
# [0.0622879  0.06137374 0.14329723 0.         0.14565149 0.02312942
#  0.06374053 0.13191409 0.00020036]

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
# Split our data
train, test, train_labels, test_labels = train_test_split(features,
                                                          labels,
                                                          test_size=0.33,
                                                          random_state=42)

# Initialize our classifier
gnb = GaussianNB()

# Train our classifier
model = gnb.fit(train, train_labels)

preds = gnb.predict(test)
print(preds)

print(test_labels.count(0))
print(test_labels.count(1))
# Evaluate accuracy
print(accuracy_score(test_labels, preds))
# Out:
# [0 0 1 ... 0 1 0]
# 18142
# 8210
# 0.9810640558591378

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns
import pandas as pd
from pylab import savefig
import matplotlib.pyplot as plt
# %matplotlib inline
cm = confusion_matrix(test_labels, preds)
cm= cm.T



cm_matrix = pd.DataFrame(data=cm, columns=['Attack free', 'Attacked'], 
                                 index=['   Attack free ', ' Attacked'])
sns.set(font_scale=2.0)
sns.heatmap(cm_matrix, annot=True, fmt= 'd', cmap='YlGnBu')
# plt.title("Confusion Matrix for All attack")
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.yticks(rotation = 80)
plt.xticks(rotation = 10)
plt.rcParams['font.size'] = 4
plt.rcParams['figure.figsize'] = (1, 1)   
plt.savefig('confusion_.pdf', bbox_inches = "tight")
plt.savefig('confusion_.PNG', bbox_inches = "tight")
plt.savefig('confusion_.svg', bbox_inches = "tight")
# cls = classification_report(test_labels, preds, digits = 5)
# figure2 = cls.get_figure()
# figure2.savefig('svm_conf2.pdf')

#plt.rcParams['font.size'] = 12
# # plot histogram with 10 bins
# plt.hist(preds, bins = 10)

# plt.xlabel('Predicted')
# plt.ylabel('Frequency')

# %%
Edges, Maximum Indegere and outdergee

[0 0 1 ... 0 1 0]
0.9754098360655737

Maximum Indegree and out degree
[0 0 1 ... 0 1 0]
0.9724878567091682


Edges, Maximum Indegere and outdergee, Maximum Pagerank
[0 0 1 ... 0 1 0]
0.97632058287796


nodes Edges, Maximum Indegere and outdergee
[0 0 1 ... 0 1 0]
0.9796220400728597

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)   
plt.boxplot(98, showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6aca2f9048>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6aca2f9b00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6aca2f09e8>],
#  'means': [<matplotlib.lines.Line2D at 0x7f6aca2f0668>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6aca2f02b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6aca2f9390>,
#   <matplotlib.lines.Line2D at 0x7f6aca2f9748>]}

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns
import pandas as pd
from pylab import savefig
import matplotlib.pyplot as plt
# %matplotlib inline
cm = confusion_matrix(test_labels, preds)



cm_matrix = pd.DataFrame(data=cm, columns=['Attack free', 'Attacked'], 
                                 index=['   Attack free ', ' Attacked'])
sns.set(font_scale=2.0)
sns.heatmap(cm_matrix, annot=True, fmt= 'd', cmap='YlGnBu')
# plt.title("Confusion Matrix for All attack")
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.yticks(rotation = 80)
plt.xticks(rotation = 10)
plt.rcParams['font.size'] = 4
plt.rcParams['figure.figsize'] = (1, 1)   
plt.savefig('confusion_.pdf', bbox_inches = "tight")
plt.savefig('confusion_.PNG', bbox_inches = "tight")
plt.savefig('confusion_.svg', bbox_inches = "tight")
# cls = classification_report(test_labels, preds, digits = 5)
# figure2 = cls.get_figure()
# figure2.savefig('svm_conf2.pdf')

#plt.rcParams['font.size'] = 12
# # plot histogram with 10 bins
# plt.hist(preds, bins = 10)

# plt.xlabel('Predicted')
# plt.ylabel('Frequency')

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import roc_curve
from sklearn import naive_bayes as nb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import metrics

nB = nb.GaussianNB()
model = nB.fit(train, train_labels)
preds = nB.predict(test)
fprG, tprG, thresholdsG = roc_curve(test_labels, preds)
print("Gausian Naive Bayes")
print(preds)
print(classification_report(test_labels, preds))

print("\n")
nB = nb.MultinomialNB()
model = nB.fit(train, train_labels)
preds = nB.predict(test)
fprM, tprM, thresholdsM = roc_curve(test_labels, preds)
print("Multinomial Naive Bayes")
print(preds)
print(accuracy_score(test_labels, preds))
print(classification_report(test_labels, preds))

print("\n")
nB = nb.ComplementNB()
model = nB.fit(train, train_labels)
preds = nB.predict(test)
fprC, tprC, thresholdsC = roc_curve(test_labels, preds)
print("Complement Naive Bayes")
print(preds)
print(accuracy_score(test_labels, preds))
print(classification_report(test_labels, preds))

print("\n")
nB = nb.BernoulliNB()
model = nB.fit(train, train_labels)
preds = nB.predict(test)
fprB, tprB, thresholdsB = roc_curve(test_labels, preds)
print("Bernoulli Naive Bayes")
print(preds)
print(accuracy_score(test_labels, preds))
print(classification_report(test_labels, preds))
print("\n")
nB = nb.CategoricalNB()


X_train_voc_cat = pd.DataFrame(train).applymap(lambda el: el if el > 0 else 0)

model = nB.fit(X_train_voc_cat, train_labels)
X_test = pd.DataFrame(test).applymap(lambda el: 1 if el == 1 else 0)
preds = nB.predict(X_test)
fprCc, tprCc, thresholdsCc = roc_curve(test_labels, preds)
print("Categorical Naive Bayes")
print(preds)
print(accuracy_score(test_labels, preds))
print(classification_report(test_labels, preds))
# Out:
# Gausian Naive Bayes
# [0 0 1 ... 0 0 0]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      9911
#            1       0.99      0.89      0.94      3842
#
#     accuracy                           0.97     13753
#    macro avg       0.98      0.95      0.96     13753
# weighted avg       0.97      0.97      0.97     13753
#
#
#
# Multinomial Naive Bayes
# [0 0 1 ... 0 0 0]
# 0.9696793426888679
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      9911
#            1       1.00      0.89      0.94      3842
#
#     accuracy                           0.97     13753
#    macro avg       0.98      0.95      0.96     13753
# weighted avg       0.97      0.97      0.97     13753
#
#
#
# Complement Naive Bayes
# [0 0 1 ... 0 0 0]
# 0.9696793426888679
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      9911
# ...

# %%
from sklearn.metrics import roc_curve



plt.figure(figsize=(6,4))

plt.plot(fprG, tprG, color = 'red', label = "GNB") #, linewidth=2)
plt.plot(fprM, tprM, color = 'blue', label = "MNB")#,linewidth=2)
plt.plot(fprC, tprC, color = 'green', label = "CNB")#,linewidth=2)
plt.plot(fprB, tprB, color = 'cyan',label = "BNB")#, linewidth=2)
#plt.plot(fprCc, tprCc, color = 'yellow',label = "CcNB")#, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 10
plt.legend()


plt.xlabel('False positive rate')

plt.ylabel('True positive rate')

plt.savefig('roc_curve_all_without_CcnB.pdf', bbox_inches = "tight")
plt.savefig('roc_curve_all_without_CcnB.PNG', bbox_inches = "tight")
plt.savefig('roc_curve_all_without_CcnB.svg', bbox_inches = "tight")

# %%
from sklearn.inspection import permutation_importance
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2)

gaussian_nb = GaussianNB()
gaussian_nb.fit(X_train, y_train)

imps = permutation_importance(gaussian_nb, X_test, y_test)
print(imps.importances_mean)
an = ["Nodes","Edges","Maximum Indegree","Minimum Indegree","Maximum Outdegree","Minimum Outdegree", "Median PageRank",
      "Maximum PageRank","Minimum PageRank"]
plt.bar(an, np.array(imps.importances_mean), width = .8, align='center', alpha=0.5)
plt.xticks(rotation=45, ha ='right', fontsize = 15)
plt.ylabel('Features importance mean', fontsize = 15)
plt.tick_params(labelsize=15)
plt.savefig('feature_importance_replay.PNG', bbox_inches = "tight")
plt.savefig('feature_importance_replay.svg', bbox_inches = "tight")
plt.savefig('feature_importance_replay.pdf', bbox_inches = "tight")
