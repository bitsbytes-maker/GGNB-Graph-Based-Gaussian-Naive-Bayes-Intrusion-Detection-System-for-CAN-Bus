# %%
# !unzip /content/AttackSpoofwithAttackFree.zip
# Out:
# Archive:  /content/AttackSpoofwithAttackFree.zip
#   inflating: AttackSpoofwithAttackFree.txt
#   inflating: IdSpoofwithAttackFree.txt

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-geometric

# %%
import torch
from torch_geometric.data import Data

edge_index = torch.tensor([[0, 1, 3, 4],
                           [1, 0, 1, 1]], dtype=torch.long)
x = torch.tensor([[-1], [0], [1]], dtype=torch.float)

data = Data(x=x, edge_index=edge_index.t().contiguous())

print(data['x'])

# %%
import numpy as np


fileId = open('/content/IdSpoofwithAttackFree.txt', 'r')
fileA = open('/content/AttackSpoofwithAttackFree.txt','r')
detectList = []
counter = 1
graphList = []
ultimateGraphList = [] 
utlimateaDetectionList = []
graphCounter = 0


messageSize = 200

for line in fileId:
  node = line.split()[0]


  graphList.append(node)
  

  if len(graphList) == messageSize: 
    ultimateGraphList.append(graphList)


    
  
   

    graphList = []
   
   

ugl = ultimateGraphList

for line in fileA:
  attackChecking = line.split()[0]


  detectList.append(attackChecking)
  

  if len(detectList) == messageSize: 
    utlimateaDetectionList.append(detectList)


    detectList = []

udl = utlimateaDetectionList


print(len(ugl))
print(len(udl))

print(ugl[0])
print(len(ugl[0]))
print(len(udl[0]))
print(udl[0])
print(udl[3])
# Out:
# 41674
# 41674
# ['0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0690', '0316', '018f', '0260', '02a0', '0329', '0545', '05f0', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '00a0', '00a1', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '04f0', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '0316', '018f', '0260', '02a0', '0329', '0545', '05f0', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '018f', '0260', '02a0', '0316', '0329', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440']
# 200
# 200
# ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']
# ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']

# %%
#Making graph from the 200 sequential of id and store them in a file as Graph adjacent list
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
import torch
from scipy.sparse import csr_matrix
from torch_geometric.data import Data, DataLoader
gAttackfree=nx.DiGraph()
gAttacked = nx.DiGraph()

lenugl = len(ugl)

counter = 0
gAttackfreeCounter = 0
gAttackedCounter = 0



allLabelList = []
nodeFeatureList = []
uvList = []
DataList = []
for i in range(0,lenugl):
  uList = []
  vList = []
  attackFree = 0
  fList = []
  all_unique_nodes = list(set(ugl[i]))
  ln = len(all_unique_nodes)
  array = np.zeros((ln,ln))
  for j in range (0, len(ugl[i])-1):
     u = all_unique_nodes.index(ugl[i][j])
     v = all_unique_nodes.index(ugl[i][j+1])
     uList.append(u)
     vList.append(v)
     array[u][v] = array[u][v]+1
  uvList.append([uList,vList])
  edge_index =  torch.LongTensor([uList,vList])
  
  for k in range(len(array)):
    indeg = 0
    outdeg = 0
    for l in range(len(array[k])):
      outdeg = outdeg + array[k][l]
      indeg = indeg + array[l][k]
    fList.append([indeg,outdeg])
  
  nodeFeatureList.append(fList)
  x = torch.FloatTensor(fList)


  for j in range (0,len(ugl[i])):
    if udl[i][j] == 'S': 
      attackFree = 1
      break

  y = attackFree
  
  allLabelList.append(attackFree)

  DataList.append(Data(x = x,edge_index=edge_index,y=y))




print(uvList[0])
print(allLabelList.count(0))
print(allLabelList.count(1))

print(nodeFeatureList[3])
# Out:
# [[21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 23, 21, 0, 22, 16, 8, 6, 14, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 2, 15, 13, 11, 9, 17, 18, 7, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 21, 0, 22, 16, 8, 20, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 14, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 0, 22, 16, 21, 8, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3], [0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 23, 21, 0, 22, 16, 8, 6, 14, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 2, 15, 13, 11, 9, 17, 18, 7, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 21, 0, 22, 16, 8, 20, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 21, 0, 22, 16, 8, 6, 14, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4, 10, 20, 0, 22, 16, 21, 8, 6, 2, 15, 13, 11, 9, 17, 12, 1, 5, 3, 19, 4, 10, 21, 0, 22, 16, 8, 6, 2, 17, 9, 12, 1, 5, 19, 3, 4]]
# 31062
# 10612
# [[11.0, 11.0], [11.0, 11.0], [10.0, 10.0], [11.0, 11.0], [11.0, 11.0], [11.0, 11.0], [10.0, 10.0], [1.0, 1.0], [11.0, 11.0], [11.0, 11.0], [11.0, 11.0], [5.0, 5.0], [11.0, 11.0], [5.0, 5.0], [2.0, 2.0], [5.0, 5.0], [11.0, 11.0], [10.0, 11.0], [1.0, 1.0], [11.0, 11.0], [6.0, 5.0], [11.0, 11.0], [11.0, 11.0], [1.0, 1.0]]

# %%
import random 


torch.manual_seed(12345)
random.shuffle(DataList)

dataset = DataList


train_size = int(lenugl*.70)

#print(int(train_size))


train_dataset = dataset[:train_size]
test_dataset = dataset[train_size:lenugl]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 29171
# Number of test graphs: 12503

# %%
from torch_geometric.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=128, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1541], edge_index=[2, 12736], x=[1541, 2], y=[64])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1540], edge_index=[2, 12736], x=[1540, 2], y=[64])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1546], edge_index=[2, 12736], x=[1546, 2], y=[64])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1542], edge_index=[2, 12736], x=[1542, 2], y=[64])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1546], edge_index=[2, 12736], x=[1546, 2], y=[64])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1540], edge_index=[2, 12736], x=[1540, 2], y=[64])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 81:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 82:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 83:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1540], edge_index=[2, 12736], x=[1540, 2], y=[64])
#
# Step 84:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 85:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 86:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 87:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 88:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 89:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 90:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 91:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1541], edge_index=[2, 12736], x=[1541, 2], y=[64])
#
# Step 92:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 93:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 94:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 95:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 96:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 97:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 98:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 99:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 100:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 101:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 102:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 103:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 104:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 105:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 106:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 107:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 108:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 109:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1586], edge_index=[2, 12736], x=[1586, 2], y=[64])
#
# Step 110:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 111:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 112:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1574], edge_index=[2, 12736], x=[1574, 2], y=[64])
#
# Step 113:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 114:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 115:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1581], edge_index=[2, 12736], x=[1581, 2], y=[64])
#
# Step 116:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 117:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1546], edge_index=[2, 12736], x=[1546, 2], y=[64])
#
# Step 118:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 119:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 120:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 121:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 122:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 123:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1577], edge_index=[2, 12736], x=[1577, 2], y=[64])
#
# Step 124:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 125:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 126:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 127:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 128:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 129:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 130:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 131:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 132:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 133:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 134:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 135:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 136:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 137:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 138:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 139:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 140:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 141:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 142:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 143:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1587], edge_index=[2, 12736], x=[1587, 2], y=[64])
#
# Step 144:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 145:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 146:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 147:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 148:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 149:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 150:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 151:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 152:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 153:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 154:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 155:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 156:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 157:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 158:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1542], edge_index=[2, 12736], x=[1542, 2], y=[64])
#
# Step 159:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 160:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 161:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 162:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 163:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 164:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 165:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 166:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 167:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 168:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 169:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 170:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1574], edge_index=[2, 12736], x=[1574, 2], y=[64])
#
# Step 171:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 172:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 173:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1542], edge_index=[2, 12736], x=[1542, 2], y=[64])
#
# Step 174:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1532], edge_index=[2, 12736], x=[1532, 2], y=[64])
#
# Step 175:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 176:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 177:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 178:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 179:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 180:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 181:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 182:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 183:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 184:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 185:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 186:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 187:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 188:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1537], edge_index=[2, 12736], x=[1537, 2], y=[64])
#
# Step 189:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 190:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 191:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 192:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 193:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 194:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 195:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 196:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 197:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 198:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 199:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 200:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 201:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 202:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 203:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 204:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1536], edge_index=[2, 12736], x=[1536, 2], y=[64])
#
# Step 205:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 206:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 207:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 208:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 209:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 210:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 211:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 212:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 213:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 214:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 215:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 216:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 217:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 218:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 219:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 220:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 221:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 222:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1577], edge_index=[2, 12736], x=[1577, 2], y=[64])
#
# Step 223:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 224:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 225:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 226:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 227:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 228:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 229:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 230:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 231:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 232:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 233:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 234:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 235:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 236:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 237:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 238:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 239:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 240:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1545], edge_index=[2, 12736], x=[1545, 2], y=[64])
#
# Step 241:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 242:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1578], edge_index=[2, 12736], x=[1578, 2], y=[64])
#
# Step 243:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 244:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1589], edge_index=[2, 12736], x=[1589, 2], y=[64])
#
# Step 245:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 246:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 247:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 248:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 249:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 250:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 251:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 252:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 253:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 254:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 255:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 256:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 257:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 258:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 259:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 260:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 261:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 262:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 263:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 264:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 265:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 266:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 267:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 268:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 269:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 270:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 271:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 272:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 273:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 274:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 275:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 276:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 277:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 278:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 279:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 280:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 281:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 282:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 283:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 284:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 285:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 286:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 287:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 288:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 289:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 290:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1577], edge_index=[2, 12736], x=[1577, 2], y=[64])
#
# Step 291:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 292:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 293:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 294:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 295:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 296:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 297:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 298:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 299:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 300:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 301:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 302:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 303:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 304:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 305:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 306:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 307:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 308:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 309:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 310:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 311:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 312:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 313:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 314:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 315:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 316:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 317:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1572], edge_index=[2, 12736], x=[1572, 2], y=[64])
#
# Step 318:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 319:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 320:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 321:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 322:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 323:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 324:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 325:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 326:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 327:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 328:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 329:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1574], edge_index=[2, 12736], x=[1574, 2], y=[64])
#
# Step 330:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1572], edge_index=[2, 12736], x=[1572, 2], y=[64])
#
# Step 331:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 332:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 333:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1547], edge_index=[2, 12736], x=[1547, 2], y=[64])
#
# Step 334:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 335:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 336:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 337:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 338:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 339:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 340:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 341:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 342:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 343:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1542], edge_index=[2, 12736], x=[1542, 2], y=[64])
#
# Step 344:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 345:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 346:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 347:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1555], edge_index=[2, 12736], x=[1555, 2], y=[64])
#
# Step 348:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 349:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 350:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1537], edge_index=[2, 12736], x=[1537, 2], y=[64])
#
# Step 351:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 352:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 353:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 354:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 355:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 356:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 357:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 358:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 359:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 360:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 361:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 362:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 363:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 364:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1544], edge_index=[2, 12736], x=[1544, 2], y=[64])
#
# Step 365:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1551], edge_index=[2, 12736], x=[1551, 2], y=[64])
#
# Step 366:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1538], edge_index=[2, 12736], x=[1538, 2], y=[64])
#
# Step 367:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 368:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1546], edge_index=[2, 12736], x=[1546, 2], y=[64])
#
# Step 369:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 370:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 371:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 372:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1536], edge_index=[2, 12736], x=[1536, 2], y=[64])
#
# Step 373:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 374:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1576], edge_index=[2, 12736], x=[1576, 2], y=[64])
#
# Step 375:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 376:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 377:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 378:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 379:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 380:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 381:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 382:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 383:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1554], edge_index=[2, 12736], x=[1554, 2], y=[64])
#
# Step 384:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 385:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1572], edge_index=[2, 12736], x=[1572, 2], y=[64])
#
# Step 386:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 387:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 388:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 389:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 390:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1553], edge_index=[2, 12736], x=[1553, 2], y=[64])
#
# Step 391:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 392:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 393:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 394:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 395:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 396:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 397:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 398:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 399:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 400:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 401:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 402:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1573], edge_index=[2, 12736], x=[1573, 2], y=[64])
#
# Step 403:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 404:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 405:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1577], edge_index=[2, 12736], x=[1577, 2], y=[64])
#
# Step 406:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 407:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 408:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 409:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 410:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 411:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1557], edge_index=[2, 12736], x=[1557, 2], y=[64])
#
# Step 412:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 413:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 414:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1549], edge_index=[2, 12736], x=[1549, 2], y=[64])
#
# Step 415:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 416:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 417:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 418:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1560], edge_index=[2, 12736], x=[1560, 2], y=[64])
#
# Step 419:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1575], edge_index=[2, 12736], x=[1575, 2], y=[64])
#
# Step 420:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 421:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 422:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1582], edge_index=[2, 12736], x=[1582, 2], y=[64])
#
# Step 423:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1578], edge_index=[2, 12736], x=[1578, 2], y=[64])
#
# Step 424:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 425:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1544], edge_index=[2, 12736], x=[1544, 2], y=[64])
#
# Step 426:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1570], edge_index=[2, 12736], x=[1570, 2], y=[64])
#
# Step 427:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 428:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1579], edge_index=[2, 12736], x=[1579, 2], y=[64])
#
# Step 429:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 430:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1565], edge_index=[2, 12736], x=[1565, 2], y=[64])
#
# Step 431:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1561], edge_index=[2, 12736], x=[1561, 2], y=[64])
#
# Step 432:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1568], edge_index=[2, 12736], x=[1568, 2], y=[64])
#
# Step 433:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1550], edge_index=[2, 12736], x=[1550, 2], y=[64])
#
# Step 434:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1556], edge_index=[2, 12736], x=[1556, 2], y=[64])
#
# Step 435:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1562], edge_index=[2, 12736], x=[1562, 2], y=[64])
#
# Step 436:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 437:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 438:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 439:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 440:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1572], edge_index=[2, 12736], x=[1572, 2], y=[64])
#
# Step 441:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1566], edge_index=[2, 12736], x=[1566, 2], y=[64])
#
# Step 442:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1569], edge_index=[2, 12736], x=[1569, 2], y=[64])
#
# Step 443:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1558], edge_index=[2, 12736], x=[1558, 2], y=[64])
#
# Step 444:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1567], edge_index=[2, 12736], x=[1567, 2], y=[64])
#
# Step 445:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 446:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1543], edge_index=[2, 12736], x=[1543, 2], y=[64])
#
# Step 447:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1548], edge_index=[2, 12736], x=[1548, 2], y=[64])
#
# Step 448:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1545], edge_index=[2, 12736], x=[1545, 2], y=[64])
#
# Step 449:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1552], edge_index=[2, 12736], x=[1552, 2], y=[64])
#
# Step 450:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 451:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1559], edge_index=[2, 12736], x=[1559, 2], y=[64])
#
# Step 452:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1564], edge_index=[2, 12736], x=[1564, 2], y=[64])
#
# Step 453:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1572], edge_index=[2, 12736], x=[1572, 2], y=[64])
#
# Step 454:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1563], edge_index=[2, 12736], x=[1563, 2], y=[64])
#
# Step 455:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1571], edge_index=[2, 12736], x=[1571, 2], y=[64])
#
# Step 456:
# =======
# Number of graphs in the current batch: 51
# Batch(batch=[1246], edge_index=[2, 10149], x=[1246, 2], y=[51])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(2, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(2, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from IPython.display import Javascript
from sklearn.metrics import confusion_matrix
import numpy as np

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
yTrue = []
yPred = []

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.


kkkk = 11
for epoch in range(1, kkkk):
    train()
    train_acc = test(train_loader)
    
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.9926
# Epoch: 002, Train Acc: 0.9937
# Epoch: 003, Train Acc: 0.9904
# Epoch: 004, Train Acc: 0.9915
# Epoch: 005, Train Acc: 0.9894
# Epoch: 006, Train Acc: 0.9934
# Epoch: 007, Train Acc: 0.9917
# Epoch: 008, Train Acc: 0.9914
# Epoch: 009, Train Acc: 0.9947
# Epoch: 010, Train Acc: 0.9920

# %%
from sklearn.metrics import confusion_matrix

def conf(yTrue,yPred):
  tp,tn,fp,fn = 0,0,0,0
  for i in range(len(yTrue)):
    if yTrue[i] == yPred[i] and yTrue[i] == 1:
      tn= tn+1

    elif yTrue[i] == yPred[i] and yTrue[i] == 0:
      tp = tp+1
    elif yTrue[i] == 0 and yPred[i] == 1:
      fp=fp+1
    else:
      fn=fn+1
  

  return np.array([[tp,fp],[fn,tn]])
    




def test1(loader):
     model.eval()

     correct = 0
     cf = np.array([[0,0],[0,0]])
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct +=(data.y).sum()  # Check against ground-truth labels.
         c=conf(np.array(data.y),np.array(pred))
         print(c)

         cf = cf+c
     print(correct)
      

     return cf  # Derive ratio of correct predictions.

print('isafhksfh')
cf = test1(test_loader)  


cf = cf.T
print(cf)
print((cf[0][0]+cf[1][1])/(cf[0][0]+cf[0][1]+cf[1][0]+cf[1][1]))
# Out:
# isafhksfh
# [[105   0]
#  [  2  21]]
# [[97  0]
#  [ 0 31]]
# [[97  0]
#  [ 1 30]]
# [[98  1]
#  [ 1 28]]
# [[96  0]
#  [ 0 32]]
# [[81  0]
#  [ 3 44]]
# [[96  0]
#  [ 1 31]]
# [[93  0]
#  [ 0 35]]
# [[100   0]
#  [  2  26]]
# [[95  0]
#  [ 0 33]]
# [[97  0]
#  [ 2 29]]
# [[95  0]
#  [ 0 33]]
# [[96  0]
#  [ 0 32]]
# [[100   0]
#  [  0  28]]
# [[95  0]
#  [ 0 33]]
# [[97  0]
#  [ 1 30]]
# [[103   0]
#  [  1  24]]
# [[97  0]
#  [ 0 31]]
# [[100   0]
#  [  3  25]]
# [[88  0]
#  [ 1 39]]
# [[89  0]
#  [ 0 39]]
# [[98  0]
#  [ 2 28]]
# [[99  0]
#  [ 0 29]]
# [[93  0]
#  [ 2 33]]
# [[95  0]
#  [ 0 33]]
# [[89  0]
#  [ 3 36]]
# [[97  0]
#  [ 0 31]]
# [[95  0]
#  [ 1 32]]
# [[102   0]
#  [  0  26]]
# [[93  0]
#  [ 2 33]]
# [[95  0]
#  [ 1 32]]
# [[100   0]
#  [  1  27]]
# [[100   0]
#  [  0  28]]
# [[93  0]
#  [ 2 33]]
# [[100   0]
#  [  1  27]]
# [[99  0]
#  [ 0 29]]
# [[104   0]
#  [  1  23]]
# [[96  0]
#  [ 2 30]]
# [[99  0]
#  [ 1 28]]
# [[103   0]
#  [  1  24]]
# [[93  0]
#  [ 0 35]]
# [[106   0]
#  [  0  22]]
# [[94  0]
#  [ 0 34]]
# [[99  0]
#  [ 0 29]]
# [[97  0]
#  [ 0 31]]
# [[98  0]
#  [ 2 28]]
# [[91  0]
#  [ 1 36]]
# [[100   0]
#  [  0  28]]
# [[97  0]
#  [ 2 29]]
# [[87  0]
#  [ 0 41]]
# [[96  0]
#  [ 2 30]]
# [[93  0]
#  [ 0 35]]
# [[96  0]
#  [ 0 32]]
# [[91  1]
#  [ 1 35]]
# [[100   0]
#  [  1  27]]
# [[93  0]
#  [ 0 35]]
# [[103   0]
#  [  0  25]]
# [[94  0]
#  [ 2 32]]
# [[99  0]
#  [ 1 28]]
# [[104   0]
#  [  0  24]]
# [[97  0]
#  [ 0 31]]
# [[96  0]
#  [ 2 30]]
# [[83  0]
#  [ 2 43]]
# [[109   0]
#  [  0  19]]
# [[101   0]
#  [  2  25]]
# [[92  0]
#  [ 0 36]]
# [[101   0]
#  [  1  26]]
# [[98  0]
#  [ 0 30]]
# [[95  0]
#  [ 0 33]]
# [[93  0]
#  [ 1 34]]
# [[97  0]
#  [ 1 30]]
# [[90  0]
#  [ 0 38]]
# [[81  0]
#  [ 2 45]]
# [[96  0]
#  [ 1 31]]
# [[97  0]
#  [ 1 30]]
# [[93  0]
#  [ 0 35]]
# [[98  0]
#  [ 3 27]]
# [[90  0]
#  [ 3 35]]
# [[96  0]
#  [ 2 30]]
# [[99  0]
#  [ 0 29]]
# [[103   0]
#  [  0  25]]
# [[95  0]
#  [ 0 33]]
# [[92  1]
#  [ 1 34]]
# [[94  0]
#  [ 1 33]]
# [[106   0]
#  [  1  21]]
# [[88  0]
#  [ 0 40]]
# [[100   0]
#  [  0  28]]
# [[89  0]
#  [ 0 39]]
# [[95  0]
#  [ 1 32]]
# [[86  0]
#  [ 1 41]]
# [[88  0]
#  [ 1 39]]
# [[93  0]
#  [ 2 33]]
# [[95  0]
#  [ 1 32]]
# [[95  0]
#  [ 0 33]]
# [[94  0]
#  [ 2 32]]
# [[92  0]
#  [ 1 35]]
# [[96  0]
#  [ 2 30]]
# [[71  0]
#  [ 1 15]]
# tensor(3130)
# [[9370   86]
#  [   3 3044]]
# 0.9928817083899864

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np



cm = cf


cm_matrix = pd.DataFrame(data=cm, columns=["Attack free","Spoofing attacks"], 
                                 index=["Attack free","Spoofing attacks"])
sns.set(font_scale=2.0)
sns.heatmap(cm_matrix, annot=True, fmt= 'g', cmap='YlGnBu')
plt.rcParams['font.size'] = 3
plt.rcParams['figure.figsize'] = (3, 3)  
# plt.title("Confusion Matrix for All attack")
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.yticks(rotation = 45)
plt.xticks(rotation = 45, ha = 'right')
 
plt.savefig('confusion_spoof.pdf', bbox_inches = "tight")
# plt.savefig('confusion_spoof.svg', bbox_inches = "tight")
# plt.savefig('confusion_spoof.png', bbox_inches = "tight")

# %%
cm = [[3735 ,  38],
 [   8 ,3152]]


tp = cm[0][0]
tn = cm[1][1]
fp = cm[0][1]
fn = cm[1][0]

re = tp/(tp+fn)
pr = tp/(tp+fp)
f1 = 2*pr*re/(pr+re)
fpr = fp / (fp+tn)
print("pr.........."+str(pr))
print("re----"+str(re))

print("f1===="+str(f1))
print("fpr====="+ str(fpr))
print((tp+tn)/(tp+tn+fp+fn))
# Out:
# pr..........0.9899284389080307
# re----0.9978626769970612
# f1====0.9938797232570517
# fpr=====0.011912225705329153
# 0.9933650656281552

# %%
71002
170939
0.991287131986724
[[170760   1929]
 [   179  69073]]
 5

35791
85180
0.9906010531449686
[[84065    22]
 [ 1115 35769]]
 10


3659
8438
0.9962800694387038
[[8424   31]
 [  14 3628]]
100


1832
4217
0.993387336749876
[[4197   20]
 [  20 1812]]

803
1617
0.993801652892562
[[1612   10]
 [   5  793]]
 500



 464
746
0.9917355371900827
[[743   7]
 [  3 457]]
 1000



 309
296
0.9917355371900827
[[294   3]
 [  2 306]]
 2k

 175
67
1.0
[[ 67   0]
 [  0 175]]
 5k


 88
33
1.0
[[33  0]
 [ 0 88]]
 10k

# %%
cm =[ [[170760 ,  1929],
 [179 , 69073]],

 [[84065   , 22],
 [ 1115, 35769]],

[[8424 ,  31],
 [  14, 3628]],

 [[4197 ,  20],
 [  20 ,1812]],

 [[1612  , 10],
 [   5  ,793]],

[[743 ,  7],
 [  3 ,457]],


 [[ 67 ,  0],
 [  0 ,175]],

 [[33,  0],
 [ 0, 88]]
]

for i in range(len(cm)):

  tp = cm[i][0][0]
  tn = cm[i][1][1]
  fp = cm[i][0][1]
  fn = cm[i][1][0]

  re = tp/(tp+fn)
  pr = tp/(tp+fp)
  f1 = 2*pr*re/(pr+re)
  fpr = fp / (fp+tn)


  mcc = (tp*tn-fp*fn)/((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))**.5

  fdr = fp/(fp+tp)

  # print("pr.........."+str(pr))
  # print("re----"+str(re))

  # print("f1===="+str(f1))
  # print("fpr====="+ str(fpr))
  print("mcccccc--------->" +str(mcc))
  #print("fdr======="+str(fdr))
  # print((tp+tn)/(tp+tn+fp+fn))
# Out:
# mcccccc--------->0.9789880325873227
# mcccccc--------->0.9778659028555149
# mcccccc--------->0.991178167512607
# mcccccc--------->0.9843402613459972
# mcccccc--------->0.9860106010676708
# mcccccc--------->0.9825172905181248
# mcccccc--------->1.0
# mcccccc--------->1.0

# %%
import pandas as pd

square_node_data = pd.DataFrame(
    {"x": [1, 2, 3, 4], "y": [-0.2, 0.3, 0.0, -0.5]}, index=["a", "b", "c", "d"]
)
square_node_data
# Out:
#    x    y
# a  1 -0.2
# b  2  0.3
# c  3  0.0
# d  4 -0.5

# %%
# Out:
#       Nodes  Edges  ...  MaximumPagerank  MininumPagerank
# No.                 ...
# 1        27    112  ...         0.215139         0.011104
# 2        25     75  ...         0.359649         0.018228
# 3        25     88  ...         0.285778         0.015716
# 4        27     97  ...         0.276848         0.014271
# 5        27    137  ...         0.173902         0.013195
# ...     ...    ...  ...              ...              ...
# 1828     26     70  ...         0.077329         0.013768
# 1829     26     73  ...         0.073358         0.011842
# 1830     26     78  ...         0.067820         0.011954
# 1831     26     85  ...         0.071132         0.009662
# 1832     26     76  ...         0.086512         0.008505
#
# [1832 rows x 9 columns]
# StellarGraph: Undirected multigraph
#  Nodes: 1832, Edges: 0
#
#  Node types:
#   default: [1832]
#     Features: float32 vector, length 9
#     Edge types: none
#
#  Edge types:
