# %%
# !unzip /content/Fuzzy_dataset.csv.zip
# Out:
# Archive:  /content/Fuzzy_dataset.csv.zip
#   inflating: Fuzzy_dataset.csv
#    creating: __MACOSX/
#   inflating: __MACOSX/._Fuzzy_dataset.csv

# %%
# !unzip /content/RPM_dataset.zip
# !unzip /content/DoS_dataset.csv.zip
# !unzip /content/Attack_free_dataset2.txt.zip
# !unzip /content/Fuzzy_dataset.csv.zip
# Out:
# Archive:  /content/RPM_dataset.zip
#   inflating: RPM_dataset.csv
# Archive:  /content/DoS_dataset.csv.zip
#   inflating: DoS_dataset.csv
#   inflating: __MACOSX/._DoS_dataset.csv
# Archive:  /content/Attack_free_dataset2.txt.zip
#   inflating: Attack_free_dataset2.txt
#   inflating: __MACOSX/._Attack_free_dataset2.txt
# Archive:  /content/Fuzzy_dataset.csv.zip
#   inflating: Fuzzy_dataset.csv
# replace __MACOSX/._Fuzzy_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
#   inflating: __MACOSX/._Fuzzy_dataset.csv

# %%
# !unzip /content/Attack_free_dataset2.txt.zip
# Out:
# Archive:  /content/Attack_free_dataset2.txt.zip
#   inflating: Attack_free_dataset2.txt
#    creating: __MACOSX/
#   inflating: __MACOSX/._Attack_free_dataset2.txt

# %%
#fileI = open("/content/170907_impersonation.txt","r")
# fileD = open("/content/DoS_dataset.csv","r")
# fileR = open("/content/RPM_dataset.csv","r")
# fileF = open("/content/Fuzzy_dataset.csv","r")
fileAttackFree = open("/content/Attack_free_dataset2.txt","r")


fileM = open("IdAttackFree.txt","w")
# fileMA = open("AttackFuzzywithAttackFree.txt","w")

overallCounter = 1

counter = 1
# for line in fileI:
#   #print(line.split())

#   node = line.split()[3]
#   #print(node)
#   fileM.write(str(node))
#   fileM.write("\n")
#   if node == "0164" and counter >= 527250:
#     fileMA.write(str('I'))
#     fileMA.write("\n")
#   else:
#     fileMA.write(str('R'))
#     fileMA.write("\n")




#   counter +=1
#   overallCounter+=1


# for line in fileD:
#   Xpartition = line.split()[0].split(',')
  
#   node = Xpartition[1]
#   fileM.write(str(node))
#   fileM.write("\n")
#   if str(Xpartition[len(Xpartition)-1]) == 'T':
#     fileMA.write('D')
#   else:
#     fileMA.write('R')

#   fileMA.write("\n")

#   overallCounter+=1

# for line in fileR:
#   Xpartition = line.split()[0].split(',')
  
#   node = Xpartition[1]
#   #print(node)
#   fileM.write(str(node))
#   fileM.write("\n")
#   if str(Xpartition[len(Xpartition)-1]) == 'T':
#     fileMA.write('S')
#   else:
#     fileMA.write('R')
#   fileMA.write("\n")

#   overallCounter+=1

# for line in fileF:
#   Xpartition = line.split()[0].split(',')
  
#   node = Xpartition[1]
#   #print(node)
#   fileM.write(str(node))
#   fileM.write("\n")
#   if str(Xpartition[len(Xpartition)-1]) == 'T':
#     fileMA.write('F')
#   else:
#     fileMA.write('R')
#   fileMA.write("\n")

#   overallCounter+=1


for line in fileAttackFree:
  
  node = line.split()[0]
  

  if node == "ID":
    continue
  
  fileM.write(str(node))
  fileM.write("\n")
  # fileMA.write("R")
  # fileMA.write("\n")



  overallCounter+=1


fileM.close()
#fileMA.close()



print(overallCounter)
# Out:
# 3713147

# %%
a=3665771+3713146
print(a)
# Out:
# 7378917
