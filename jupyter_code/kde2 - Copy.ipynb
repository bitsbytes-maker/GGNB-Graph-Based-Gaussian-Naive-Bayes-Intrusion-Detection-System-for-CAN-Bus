# %%
import seaborn as sn
import matplotlib.pyplot as plt
import pandas



# load dataset
dataframe = pandas.read_table('/content/completeallwithNode.txt')
data = dataframe.drop("No.", axis=1)
dataset = data.values


# split into input (X) and output (Y) variables

l = 79854
#l = 18565 + 659
X = dataset[0:l,0:]
# Y = dataset[100:200, 1:10]
# print(X)
# print(X.shape)
labels = []
for i in range (0,l):
  if X[i][9] == 'T':
    labels.append(0)
  else:
    labels.append(1)

features = X[0:l,0:9]

print(labels.count(0))
print(labels.count(1))
print(features)

print(features.shape)

# df = dataframe.corr()

# #print(df)

# corrMatrix = data.corr()
# print(corrMatrix)

# sn.heatmap(corrMatrix, annot=True, fmt = ".1g")
# plt.show()
# plt.show()
# print(labels)

# print(features.shape)
#print(features)
# print(Y)
# Out:
# 54995
# 24859
# [[24 44 5 ... 0.03688071155039866 0.07360649759034145
#   0.016677714846090454]
#  [24 34 3 ... 0.04253696661055606 0.0882129092099077 0.016522395460077763]
#  [24 36 3 ... 0.04400826005008965 0.06481770478688069
#   0.016405861231623044]
#  ...
#  [42 242 20 ... 0.01962590798163142 0.0724726846867403
#   0.004699352964786049]
#  [44 241 20 ... 0.02058400848392282 0.07247380150399091
#   0.005531143028168605]
#  [42 230 22 ... 0.0221067406930489 0.0825651064928123
#   0.004773152146913031]]
# (79854, 9)

# %%
# import seaborn as sns

# data = data [ data['State'] == 'F']

# print(data)

# sns.kdeplot(data=data, 
#    fill=True, common_norm=False, palette="crest",
#    alpha=.5, linewidth=10)
# Out:
#        Nodes  Edges  MaximumIndegree  ...  MaximumPageRank  MininumPagerank  State
# 18572     22     70               19  ...         0.246255         0.019643      F
# 18573     22     48               22  ...         0.442197         0.023903      F
# 18574     24     51               24  ...         0.446801         0.022074      F
# 18575     25     54               25  ...         0.449199         0.021273      F
# 18576     25     53               25  ...         0.449999         0.021300      F
# ...      ...    ...              ...  ...              ...              ...    ...
# 79849     41    252               23  ...         0.082049         0.004705      F
# 79850     44    251               25  ...         0.086105         0.004699      F
# 79851     42    242               20  ...         0.072473         0.004699      F
# 79852     44    241               20  ...         0.072474         0.005531      F
# 79853     42    230               22  ...         0.082565         0.004773      F
#
# [24859 rows x 10 columns]

# %%
# from sklearn.preprocessing import StandardScaler
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline

# def is_invertible(a):
#   return a.shape[0] == a.shape[1] and np.linalg.matrix_rank(a) == a.shape[0]
# plt.style.use('bmh')
# plt.rcParams['figure.figsize'] = (10, 10)
# title_config = {'fontsize': 20, 'y': 1.05}

# X_train = data.iloc[:, 0:9].values
# y_train = data['State'].values

# #print(is_invertible(pd.DataFrame(X_train[y_train == 'F'])))

# plt.title('Likelihood kde plots for the attacked class', **title_config)
# plt.rcParams['font.size'] = 12
# plt.rcParams['figure.figsize'] = (1, 1) 
# plt.savefig('kde_plots_attacked_class.png', bbox_inches = "tight")
# plt.savefig('kde_plots_attacked_class.svg', bbox_inches = "tight")
# plt.savefig('kde_plots_attacked_class.pdf', bbox_inches = "tight")

# pd.DataFrame(X_train[y_train == 'T']).plot.kde(ind=100, legend=False)

# #scaled = pd.DataFrame(StandardScaler().fit_transform())

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import StandardScaler
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('bmh')
# plt.rcParams['figure.figsize'] = (10, 10)
# title_config = {'fontsize': 20, 'y': 1.05}

# X_train = data.iloc[:, 0:9].values.astype('float64')
# y_train = data['State'].values
# scaled = pd.DataFrame(StandardScaler().fit_transform(X_train))

# scaled[y_train == 'F'].plot.kde(ind=100, legend=False)
# plt.title('Likelihood KDE Plots for the Negative Class after Standardization', **title_config);

# scaled[y_train == 'T'].plot.kde(ind=100, legend=False)
# plt.title('Likelihood KDE Plots for the Positive Class after Standardization', **title_config);

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(6,4))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values

transformed = pd.DataFrame(QuantileTransformer(output_distribution='normal').fit_transform(X_train))


#print(transformed[y_train == 'F'])
transformed[y_train == 'T'].plot.kde(ind=100, legend=False)
plt.title('Likelihood KDE Plots for the Positive Class after Quantile Transformation')
plt.savefig("pclassafterquantileTransformation.png", bbox_inches = "tight")

transformed[y_train == 'F'].plot.kde(ind=100, legend=False)
plt.title('Likelihood KDE Plots for the Negative Class after Quantile Transformation')
plt.savefig("nclassafterquantileTransformation.png", bbox_inches = "tight")

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(15,10))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values

print(transformed[y_train == 'T'].mean() - transformed[y_train == 'F'].mean())
plt.hist(transformed[y_train == 'F'].mean() - transformed[y_train == 'T'].mean())

plt.ylabel('Frequency', fontsize = 30, fontweight = 'bold')
plt.xlabel('Mean diffrences between attack and attack free classes', fontsize = 30, fontweight = 'bold')
plt.tick_params(labelsize=30)
# plt.title('Histogram of sample mean differences between two classes', **title_config)
plt.savefig("mean_difference.png", bbox_inches = "tight")
plt.savefig("mean_difference.svg", bbox_inches = "tight")
plt.savefig("mean_difference.pdf", bbox_inches = "tight")
# Out:
# 0    0.246019
# 1   -1.458878
# 2   -1.545464
# 3   -0.004183
# 4   -1.552519
# 5    0.536701
# 6    1.518555
# 7   -0.654042
# 8    0.115444
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(16.4,10))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values

plt.hist(transformed[y_train == 'F'].var() - transformed[y_train == 'T'].var())

plt.xlabel('Variance differences between attack and attack free classes', fontsize = 30, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 30, fontweight = 'bold')
plt.tick_params(labelsize=30)
plt.savefig("variance_diference.png", bbox_inches = "tight")
plt.savefig("variance_diference.svg", bbox_inches = "tight")
plt.savefig("variance_diference.pdf", bbox_inches = "tight")

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(11,12))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values
#print((transformed[y_train == 'F'].var()-transformed[y_train == 'T'].var()).nsmallest(2).index)
select = (transformed[y_train == 'F'].var() - transformed[y_train == 'T'].var()).nsmallest(2).index

#print(transformed.loc[y_train == 'F'])
# print(transformed.loc[y_train == 'F', select[0]])
at = list(transformed.loc[y_train == 'T', select[1]])
af = list(transformed.loc[y_train == 'F', select[1]])

# print("maximum indegree")

# countf =  sum(map(lambda x : x >= .7, af))
# countt = sum(map(lambda x : x < .7, at))
# print(str(len(af))+"  "+ str(countf))
# print(str(len(at))+"  "+ str(countt))
# print(np.min(transformed.loc[y_train == 'F', select[0]]))
# print("maximum outdegree")
# print(transformed.loc[y_train == 'F', select[1]])
# print("median")
# print(transformed.loc[y_train == 'F', 7])
#print(transformed.loc[y_train == 'F', 9])
plt.scatter(transformed.loc[y_train == 'F', select[0]], transformed.loc[y_train == 'F', select[1]], alpha=0.5, label='Attack', s = 100)
plt.scatter(transformed.loc[y_train == 'T', select[0]], transformed.loc[y_train == 'T', select[1]], alpha=0.5, label='Attack free', s = 100)
plt.ylabel("Quantile transformed Maximum Outdegree", fontsize = 30, fontweight = 'bold')
plt.xlabel("Quantile transformed Maximum Indegree", fontsize = 30, fontweight = 'bold')
plt.tick_params(labelsize=30)
plt.legend(fontsize = 30)
#plt.legend(markerscale=2.4)
# #plt.title('Positive Class and Negative Looks in Higher Sample Variance', **title_config)
plt.savefig("higherSampleVariance.png", bbox_inches = "tight")
plt.savefig("higherSampleVariance.pdf", bbox_inches = "tight")
plt.savefig("higherSampleVariance.svg", bbox_inches = "tight")

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(10,10))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values



plt.scatter(X_train[y_train == 'F', select[0]], X_train[y_train == 'F', select[1]], alpha=0.5, label='Attack', s= 100)
plt.scatter(X_train[y_train == 'T', select[0]], X_train[y_train == 'T', select[1]], alpha=0.5, label='Attack free', s= 100)
plt.xlabel(str(data.columns[select[0]]))
plt.ylabel(str(data.columns[select[1]]))
#plt.title('Bounds in Data', **title_config)
plt.xlabel("Maximum Indegree", fontsize = 30, fontweight = 'bold')
plt.ylabel("Maximum Outdegree", fontsize = 30, fontweight = 'bold')
plt.tick_params(labelsize=30)
plt.legend(fontsize = 30);
plt.savefig("bounds_in_data.png", bbox_inches = "tight")
plt.savefig("bounds_in_data.svg", bbox_inches = "tight")
plt.savefig("bounds_in_data.pdf", bbox_inches = "tight")

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.figure(figsize=(7,7))
title_config = {'fontsize': 20, 'y': 1.05}

X_train = data.iloc[:, 0:9].values.astype('float64')
y_train = data['State'].values

size0 = (y_train == 'F').sum()
size1 = y_train.size - size0

x0 = np.random.normal(transformed.loc[y_train == 'F', select[0]].mean(),
                      transformed.loc[y_train == 'F', select[0]].std(), size=size0)

y0 = np.random.normal(transformed.loc[y_train == 'F', select[1]].mean(),
                      transformed.loc[y_train == 'F', select[1]].std(), size=size0)
x1 = np.random.normal(transformed.loc[y_train == 'T', select[0]].mean(),
                      transformed.loc[y_train == 'T', select[0]].std(), size=size1)

y1 = np.random.normal(transformed.loc[y_train == 'T', select[1]].mean(),
                      transformed.loc[y_train == 'T', select[1]].std(), size=size1)

plt.scatter(x0, y0, alpha=0.5, label='Negative')
plt.scatter(x1, y1, alpha=0.5, label='Positive')

plt.xlabel("Quantile transformed Maximum Indegree", fontsize = 15)
plt.ylabel("Quantile transformed Maximum Outdegree", fontsize = 15)
plt.tick_params(labelsize=15)

plt.legend()
plt.savefig("simulated_data.png", bbox_inches = "tight")
plt.savefig("simulated_data.pdf", bbox_inches = "tight")
plt.savefig("simulated_data.svg", bbox_inches = "tight")

# %%
# demonstration of the quantile transform
from numpy import exp
from numpy.random import randn
from sklearn.preprocessing import QuantileTransformer
from matplotlib import pyplot
# generate gaussian data sample
data = randn(1000)
# add a skew to the data distribution
data = exp(data)

# histogram of the raw data with a skew
pyplot.hist(data, bins=25)
pyplot.show()
# reshape data to have rows and columns
data = data.reshape((len(data),1))

# quantile transform the raw data
quantile = QuantileTransformer(output_distribution='normal')
data_trans = quantile.fit_transform(data)
# histogram of the transformed data
pyplot.hist(data_trans, bins=25)
pyplot.show()
