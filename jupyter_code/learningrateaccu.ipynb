# %%
import seaborn as sn
import matplotlib.pyplot as plt
import pandas
from sklearn.ensemble import RandomForestClassifier



# load dataset
dataframe = pandas.read_table('/content/complete_gdata_GraphFeatures.txt')
data = dataframe.drop("No.", axis=1)
data = data.drop("StdPageRank", axis=1)
data = data.drop("VarPageRank", axis=1)
dataset = data.values



# split into input (X) and output (Y) variables

#l = 36893 
l = 37765
X = dataset[:,0:]
# Y = dataset[100:200, 1:10]
for col in data.columns: 
    print(col)
# print(X.shape)
labels = []
for i in range (0,l):
  if X[i][9] == True:
    labels.append(0)
  else:
    labels.append(1)

features = X[0:l,0:9]

print(labels.count(0))
print(labels.count(1))
print(features)

print(features.shape)
# Out:
# Nodes
# Edges
# MaximumIndegree
# MinimumIndegree
# MaximumOutdegree
# MinimumOutdegree
# MedianPagerank
# MaximumPagerank
# MininumPagerank
# State
# 34202
# 3563
# [[57 121 9 ... 0.011847698690706312 0.0628538533783988
#   0.005226468795124438]
#  [54 113 10 ... 0.011691332678962356 0.0715180760115729
#   0.006019008683538548]
#  [59 120 9 ... 0.010858908338771551 0.058555743406307474
#   0.005263928269330575]
#  ...
#  [52 104 9 ... 0.013231465131704971 0.06380430070732221
#   0.005547068980309991]
#  [63 108 8 ... 0.01125171236654841 0.049033122874196776
#   0.004521419096159883]
#  [55 97 10 ... 0.012311706406918916 0.07104531707429775
#   0.004723919337887838]]
# (37765, 9)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

accuracyList = []

# Split our data
train, test, train_labels, test_labels = train_test_split(features,
                                                            labels,
                                                            test_size=0.33,
                                                            random_state= 42)#

  # Initialize our classifier
accuracyList = []
#Chnagin the range 
for i in range(1,100):
  gnb = AdaBoostClassifier(learning_rate=1/i) # giving the name of the model gradienboost(learning_rate = i)

    # Train our classifier
  model = gnb.fit(train, train_labels)
  preds = gnb.predict(test)
  accuracyList.append(accuracy_score(test_labels, preds))

print(np.max(accuracyList))
# Out:
# 0.9090106715879002

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1/i for i in range(1,100)],accuracyList, linewidth=2.0)
plt.xlabel("Maximum depth")
plt.ylabel("Accuracy")
plt.savefig('random.PNG', bbox_inches = "tight")

#plt.bar([i for i in range(0,1000)],np.array(accuracyList), width = .8, align='center', alpha=0.5)
