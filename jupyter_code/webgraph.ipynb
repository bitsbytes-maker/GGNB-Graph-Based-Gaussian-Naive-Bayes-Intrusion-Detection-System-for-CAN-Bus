# %%
# !git clone

# %%
# !unzip enron.zip -d data
#First upload enron.zip, then unzip it and restore it in data folder
#data folder path is /content/data/

# %%
import glob
import re
import hashlib
import networkx as nx
import time
import numpy
import operator
import math
import sys

#This function was copied from http://stackoverflow.com/questions/2545532/python-analog-of-natsort-function-sort-a-list-using-a-natural-order-algorithm
#It allows for natural sorting for the input files, so they're read in the correct order
def natural_key(string_):
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]

#Get command line args
graphFilePath = sys.argv[1:]
graphFilePath = str("/content/data")
#graphFilePath = ""
print ("Loading files from folder: " + graphFilePath)

start_time = time.clock()

#Load dataset
# files = ["datasets/enron/0_enron_by_day.txt", "datasets/enron/1_enron_by_day.txt", "datasets/enron/2_enron_by_day.txt",
# "datasets/enron/3_enron_by_day.txt", "datasets/enron/4_enron_by_day.txt"]  #
print (graphFilePath + "*.txt")
files = glob.glob(graphFilePath + "*.txt")
files = glob.glob("/content/data/*.txt")


#print(files)
sorted_files = sorted(files, key=natural_key)

# Create directed graph in networkx
list_All_Feature_Set = []

#Loop through each graph file
for file in sorted_files:
    f = open(file, "r")
    dataGraph = f.readlines()

    #Create networkx graph object
    G = nx.DiGraph()

    # Add edges to Graph object from input file
    for line in dataGraph:
        nodeA, nodeB = line.split(" ")
        # print(nodeA)
        # print(nodeB)
        nodeA.rstrip('\r\n')
        nodeB.rstrip('\r\n')
        nodeB = nodeB[:-1]
        G.add_edge(str(nodeA), str(nodeB))

    #Generate dictionary with pagerank (quality) values for each node
    weighted_Feature_Set = nx.pagerank(G)

    #print(weighted_Feature_Set)

    #Add edge "quality" from graph to weighted feature set
    for a, b in G.edges():
        weighted_Feature_Set[str(a) + " " + str(b)] = (1/len(G.edges(a))) * weighted_Feature_Set[a]
    #THIS NEEDS TO BE IMPROVED!!!

    #Convert every key to a md5 hash
    for key, value in weighted_Feature_Set.items():
        sha1_hash = hashlib.sha1(str(key).encode() + str(value).encode()).hexdigest()
        binary_hash = bin(int(sha1_hash, 16))[2:]
        #Trim to fixed size of 128
        binary_hash = (binary_hash[:128]) if len(binary_hash) > 128 else binary_hash
        #print("jksdjfskdfjdksfj")
        #print(str(binary_hash))
        
        #Add sha1 hash with corresponding value to feature set
        weighted_Feature_Set[str(binary_hash)] = value

        #print(weighted_Feature_Set)
        #Remove original key/value from feature set
        del weighted_Feature_Set[key]

    #Add file
    list_All_Feature_Set.append(weighted_Feature_Set)

    print ("Processed file: " + file)

#List of all document fingerprints
all_Fingerprints = []

#Loop through each feature set to generate it's fingerprint
for feature_Set in list_All_Feature_Set:
    temp_fingerprint = []
    #Build fingerprint
    #print("dnskjksfjsd")
    # for key in feature_Set:
    #     print(key, ' : ', feature_Set[key])
    for key, val in feature_Set.items():
        binary_list = []
        #For each sha1 hash, if digit=1 then add weighted value. If digit=0, then add negative weighted value.
        #print("sjhfasjfhsaj")
        print(key, ' : ', val)
        for d in key:
            if int(d) == 1:
                binary_list.append(val)
            else:
                binary_list.append(-val)
        temp_fingerprint.append(binary_list)

    #Calculate fingerprint by summing all the columns in temp_fingerprint
    fingerprint = [sum(x) for x in zip(*temp_fingerprint)]

    #Convert all positive vals to '1' and all negative vals to '0' in fingerprint
    for index, item in enumerate(fingerprint):
        if item > 0:
            fingerprint[index] = 1
        else:
            fingerprint[index] = 0

    #Add fingerprint to list
    all_Fingerprints.append(fingerprint)


#Calculate similarity scores (hamming distance) between each sequential pair of fingerprints
similarity_scores = []
for x in range(len(all_Fingerprints) - 1):
    hamming = 0.0
    #Calculate hamming distance
    for index in range(0, 128):
        if all_Fingerprints[x][index] == all_Fingerprints[x + 1][index]:
            hamming += 1
    similarity_scores.append(1-(hamming/128))
    #print "Similarity score between " + str(x) + " and " + str(x+1) + " : " + str(1-(hamming / 128))

#Moving Range Average
median = numpy.median(numpy.array(similarity_scores))
thresholdList = []
tempAvgNumerator = 0
multiplierForMR = 1
for y in range(len(similarity_scores)):
    if y == 0:
        tempAvgNumerator = 0
        thresholdList.append(0)
    else:
        tempAvgNumerator = tempAvgNumerator + abs(similarity_scores[y]-similarity_scores[y-1])
        threshold = median - (multiplierForMR*tempAvgNumerator/y)
        thresholdList.append(threshold)

#Detect anomalies || Look for two consecutive below threshold
anomalies = {}
anomaliesscore = {}
score = []
for x in range(len(similarity_scores)-1):
    #Detect two consecutive anomalies
    if (similarity_scores[x] < thresholdList[x]) and (similarity_scores[x+1] < thresholdList[x+1]):
        anomalies[str(x+1)] = abs(similarity_scores[x] - thresholdList[x]) + abs(similarity_scores[x+1] - thresholdList[x+1])
        anomaliesscore[str(x+1)] = similarity_scores[x+1]

###Output Anomalies###
#You will list all of the anomalous time points if
#there are fewer than 10, the top 10 if there are fewer than 100, or the top 10% if there are
#more than 100.
f = open('anomalies_output', 'w')
sorted_anomalies = sorted(anomalies.items(), key=operator.itemgetter(1), reverse=True)
numOfAnomalies = len(sorted_anomalies)
if numOfAnomalies > 100:
    print ("There are " + str(numOfAnomalies) + " anomalies found, so we will output the top 10%")
    for x in range(0,int(math.ceil(0.1*len(sorted_anomalies)))):
        f.write(str(sorted_anomalies[x][0]))
        f.write("\n")
elif numOfAnomalies > 11:
    print ("There are " + str(numOfAnomalies) + " anomalies found, so we will output the top 10")
    for x in range(0,10):
        f.write(str(sorted_anomalies[x][0]))
        f.write("\n")
else:
    print ("There are " + str(numOfAnomalies) + " anomalies found, so we will output all of them")
    for x in sorted_anomalies:
        f.write(str(x[0]))
        f.write("\n")
f.close()

print ("Complete")
print("--- Total processing took %s seconds ---" % ( time.clock() - start_time))

##DEBUGGING AND GRAPHING OUTPUT
print ("Writing out to file: anomalies_output")
#Write out to file
f = open('similarity_scores', 'w')
for x in similarity_scores:
    f.write(str(x))
    f.write("\n")
f.close()

f = open('moving_thresholds', 'w')
for x in thresholdList:
    f.write(str(x))
    f.write("\n")
f.close()
# Out:
# Loading files from folder: /content/data
# /content/data*.txt
# Processed file: /content/data/0_enron_by_day.txt
# Processed file: /content/data/1_enron_by_day.txt
# Processed file: /content/data/2_enron_by_day.txt
# Processed file: /content/data/3_enron_by_day.txt
# Processed file: /content/data/4_enron_by_day.txt
# Processed file: /content/data/5_enron_by_day.txt
# Processed file: /content/data/6_enron_by_day.txt
# Processed file: /content/data/7_enron_by_day.txt
# Processed file: /content/data/8_enron_by_day.txt
# Processed file: /content/data/9_enron_by_day.txt
# Processed file: /content/data/10_enron_by_day.txt
# Processed file: /content/data/11_enron_by_day.txt
# Processed file: /content/data/12_enron_by_day.txt
# Processed file: /content/data/13_enron_by_day.txt
# Processed file: /content/data/14_enron_by_day.txt
# Processed file: /content/data/15_enron_by_day.txt
# Processed file: /content/data/16_enron_by_day.txt
# Processed file: /content/data/17_enron_by_day.txt
# Processed file: /content/data/18_enron_by_day.txt
# Processed file: /content/data/19_enron_by_day.txt
# Processed file: /content/data/20_enron_by_day.txt
# Processed file: /content/data/21_enron_by_day.txt
# Processed file: /content/data/22_enron_by_day.txt
# Processed file: /content/data/23_enron_by_day.txt
# Processed file: /content/data/24_enron_by_day.txt
# Processed file: /content/data/25_enron_by_day.txt
# Processed file: /content/data/26_enron_by_day.txt
# Processed file: /content/data/27_enron_by_day.txt
# Processed file: /content/data/28_enron_by_day.txt
# Processed file: /content/data/29_enron_by_day.txt
# Processed file: /content/data/30_enron_by_day.txt
# Processed file: /content/data/31_enron_by_day.txt
# Processed file: /content/data/32_enron_by_day.txt
# Processed file: /content/data/33_enron_by_day.txt
# Processed file: /content/data/34_enron_by_day.txt
# Processed file: /content/data/35_enron_by_day.txt
# Processed file: /content/data/36_enron_by_day.txt
# Processed file: /content/data/37_enron_by_day.txt
# Processed file: /content/data/38_enron_by_day.txt
# Processed file: /content/data/39_enron_by_day.txt
# Processed file: /content/data/40_enron_by_day.txt
# Processed file: /content/data/41_enron_by_day.txt
# Processed file: /content/data/42_enron_by_day.txt
# Processed file: /content/data/43_enron_by_day.txt
# Processed file: /content/data/44_enron_by_day.txt
# Processed file: /content/data/45_enron_by_day.txt
# Processed file: /content/data/46_enron_by_day.txt
# Processed file: /content/data/47_enron_by_day.txt
# Processed file: /content/data/48_enron_by_day.txt
# Processed file: /content/data/49_enron_by_day.txt
# Processed file: /content/data/50_enron_by_day.txt
# Processed file: /content/data/51_enron_by_day.txt
# Processed file: /content/data/52_enron_by_day.txt
# Processed file: /content/data/53_enron_by_day.txt
# Processed file: /content/data/54_enron_by_day.txt
# Processed file: /content/data/55_enron_by_day.txt
# Processed file: /content/data/56_enron_by_day.txt
# Processed file: /content/data/57_enron_by_day.txt
# Processed file: /content/data/58_enron_by_day.txt
# Processed file: /content/data/59_enron_by_day.txt
# Processed file: /content/data/60_enron_by_day.txt
# Processed file: /content/data/61_enron_by_day.txt
# Processed file: /content/data/62_enron_by_day.txt
# Processed file: /content/data/63_enron_by_day.txt
# Processed file: /content/data/64_enron_by_day.txt
# Processed file: /content/data/65_enron_by_day.txt
# Processed file: /content/data/66_enron_by_day.txt
# Processed file: /content/data/67_enron_by_day.txt
# Processed file: /content/data/68_enron_by_day.txt
# Processed file: /content/data/69_enron_by_day.txt
# Processed file: /content/data/70_enron_by_day.txt
# Processed file: /content/data/71_enron_by_day.txt
# Processed file: /content/data/72_enron_by_day.txt
# Processed file: /content/data/73_enron_by_day.txt
# Processed file: /content/data/74_enron_by_day.txt
# Processed file: /content/data/75_enron_by_day.txt
# Processed file: /content/data/76_enron_by_day.txt
# Processed file: /content/data/77_enron_by_day.txt
# Processed file: /content/data/78_enron_by_day.txt
# Processed file: /content/data/79_enron_by_day.txt
# Processed file: /content/data/80_enron_by_day.txt
# Processed file: /content/data/81_enron_by_day.txt
# Processed file: /content/data/82_enron_by_day.txt
# Processed file: /content/data/83_enron_by_day.txt
# Processed file: /content/data/84_enron_by_day.txt
# Processed file: /content/data/85_enron_by_day.txt
# Processed file: /content/data/86_enron_by_day.txt
# Processed file: /content/data/87_enron_by_day.txt
# Processed file: /content/data/88_enron_by_day.txt
# Processed file: /content/data/89_enron_by_day.txt
# Processed file: /content/data/90_enron_by_day.txt
# Processed file: /content/data/91_enron_by_day.txt
# Processed file: /content/data/92_enron_by_day.txt
# Processed file: /content/data/93_enron_by_day.txt
# Processed file: /content/data/94_enron_by_day.txt
# Processed file: /content/data/95_enron_by_day.txt
# Processed file: /content/data/96_enron_by_day.txt
# Processed file: /content/data/97_enron_by_day.txt
# Processed file: /content/data/98_enron_by_day.txt
# Processed file: /content/data/99_enron_by_day.txt
# Processed file: /content/data/100_enron_by_day.txt
# Processed file: /content/data/101_enron_by_day.txt
# Processed file: /content/data/102_enron_by_day.txt
# Processed file: /content/data/103_enron_by_day.txt
# Processed file: /content/data/104_enron_by_day.txt
# Processed file: /content/data/105_enron_by_day.txt
# Processed file: /content/data/106_enron_by_day.txt
# Processed file: /content/data/107_enron_by_day.txt
# Processed file: /content/data/108_enron_by_day.txt
# Processed file: /content/data/109_enron_by_day.txt
# Processed file: /content/data/110_enron_by_day.txt
# Processed file: /content/data/111_enron_by_day.txt
# Processed file: /content/data/112_enron_by_day.txt
# Processed file: /content/data/113_enron_by_day.txt
# Processed file: /content/data/114_enron_by_day.txt
# Processed file: /content/data/115_enron_by_day.txt
# Processed file: /content/data/116_enron_by_day.txt
# Processed file: /content/data/117_enron_by_day.txt
# Processed file: /content/data/118_enron_by_day.txt
# Processed file: /content/data/119_enron_by_day.txt
# Processed file: /content/data/120_enron_by_day.txt
# Processed file: /content/data/121_enron_by_day.txt
# Processed file: /content/data/122_enron_by_day.txt
# Processed file: /content/data/123_enron_by_day.txt
# Processed file: /content/data/124_enron_by_day.txt
# Processed file: /content/data/125_enron_by_day.txt
# Processed file: /content/data/126_enron_by_day.txt
# Processed file: /content/data/127_enron_by_day.txt
# Processed file: /content/data/128_enron_by_day.txt
# Processed file: /content/data/129_enron_by_day.txt
# Processed file: /content/data/130_enron_by_day.txt
# Processed file: /content/data/131_enron_by_day.txt
# Processed file: /content/data/132_enron_by_day.txt
# Processed file: /content/data/133_enron_by_day.txt
# Processed file: /content/data/134_enron_by_day.txt
# Processed file: /content/data/135_enron_by_day.txt
# Processed file: /content/data/136_enron_by_day.txt
# Processed file: /content/data/137_enron_by_day.txt
# Processed file: /content/data/138_enron_by_day.txt
# Processed file: /content/data/139_enron_by_day.txt
# Processed file: /content/data/140_enron_by_day.txt
# Processed file: /content/data/141_enron_by_day.txt
# Processed file: /content/data/142_enron_by_day.txt
# Processed file: /content/data/143_enron_by_day.txt
# Processed file: /content/data/144_enron_by_day.txt
# Processed file: /content/data/145_enron_by_day.txt
# Processed file: /content/data/146_enron_by_day.txt
# Processed file: /content/data/147_enron_by_day.txt
# Processed file: /content/data/148_enron_by_day.txt
# Processed file: /content/data/149_enron_by_day.txt
# Processed file: /content/data/150_enron_by_day.txt
# Processed file: /content/data/151_enron_by_day.txt
# Processed file: /content/data/152_enron_by_day.txt
# Processed file: /content/data/153_enron_by_day.txt
# Processed file: /content/data/154_enron_by_day.txt
# Processed file: /content/data/155_enron_by_day.txt
# Processed file: /content/data/156_enron_by_day.txt
# Processed file: /content/data/157_enron_by_day.txt
# Processed file: /content/data/158_enron_by_day.txt
# Processed file: /content/data/159_enron_by_day.txt
# Processed file: /content/data/160_enron_by_day.txt
# Processed file: /content/data/161_enron_by_day.txt
# Processed file: /content/data/162_enron_by_day.txt
# Processed file: /content/data/163_enron_by_day.txt
# Processed file: /content/data/164_enron_by_day.txt
# Processed file: /content/data/165_enron_by_day.txt
# Processed file: /content/data/166_enron_by_day.txt
# Processed file: /content/data/167_enron_by_day.txt
# Processed file: /content/data/168_enron_by_day.txt
# Processed file: /content/data/169_enron_by_day.txt
# Processed file: /content/data/170_enron_by_day.txt
# Processed file: /content/data/171_enron_by_day.txt
# Processed file: /content/data/172_enron_by_day.txt
# Processed file: /content/data/173_enron_by_day.txt
# Processed file: /content/data/174_enron_by_day.txt
# Processed file: /content/data/175_enron_by_day.txt
# Processed file: /content/data/176_enron_by_day.txt
# Processed file: /content/data/177_enron_by_day.txt
# Processed file: /content/data/178_enron_by_day.txt
# Processed file: /content/data/179_enron_by_day.txt
# Processed file: /content/data/180_enron_by_day.txt
# Processed file: /content/data/181_enron_by_day.txt
# Processed file: /content/data/182_enron_by_day.txt
# Processed file: /content/data/183_enron_by_day.txt
# Processed file: /content/data/184_enron_by_day.txt
# Processed file: /content/data/185_enron_by_day.txt
# Processed file: /content/data/186_enron_by_day.txt
# Processed file: /content/data/187_enron_by_day.txt
# Processed file: /content/data/188_enron_by_day.txt
# Processed file: /content/data/189_enron_by_day.txt
# Processed file: /content/data/190_enron_by_day.txt
# Processed file: /content/data/191_enron_by_day.txt
# Processed file: /content/data/192_enron_by_day.txt
# Processed file: /content/data/193_enron_by_day.txt
# Processed file: /content/data/194_enron_by_day.txt
# Processed file: /content/data/195_enron_by_day.txt
# Processed file: /content/data/196_enron_by_day.txt
# Processed file: /content/data/197_enron_by_day.txt
# Processed file: /content/data/198_enron_by_day.txt
# Processed file: /content/data/199_enron_by_day.txt
# Processed file: /content/data/200_enron_by_day.txt
# Processed file: /content/data/201_enron_by_day.txt
# Processed file: /content/data/202_enron_by_day.txt
# Processed file: /content/data/203_enron_by_day.txt
# Processed file: /content/data/204_enron_by_day.txt
# Processed file: /content/data/205_enron_by_day.txt
# Processed file: /content/data/206_enron_by_day.txt
# Processed file: /content/data/207_enron_by_day.txt
# Processed file: /content/data/208_enron_by_day.txt
# Processed file: /content/data/209_enron_by_day.txt
# Processed file: /content/data/210_enron_by_day.txt
# Processed file: /content/data/211_enron_by_day.txt
# Processed file: /content/data/212_enron_by_day.txt
# Processed file: /content/data/213_enron_by_day.txt
# Processed file: /content/data/214_enron_by_day.txt
# Processed file: /content/data/215_enron_by_day.txt
# Processed file: /content/data/216_enron_by_day.txt
# Processed file: /content/data/217_enron_by_day.txt
# Processed file: /content/data/218_enron_by_day.txt
# Processed file: /content/data/219_enron_by_day.txt
# Processed file: /content/data/220_enron_by_day.txt
# Processed file: /content/data/221_enron_by_day.txt
# Processed file: /content/data/222_enron_by_day.txt
# Processed file: /content/data/223_enron_by_day.txt
# Processed file: /content/data/224_enron_by_day.txt
# Processed file: /content/data/225_enron_by_day.txt
# Processed file: /content/data/226_enron_by_day.txt
# Processed file: /content/data/227_enron_by_day.txt
# Processed file: /content/data/228_enron_by_day.txt
# Processed file: /content/data/229_enron_by_day.txt
# Processed file: /content/data/230_enron_by_day.txt
# Processed file: /content/data/231_enron_by_day.txt
# Processed file: /content/data/232_enron_by_day.txt
# Processed file: /content/data/233_enron_by_day.txt
# Processed file: /content/data/234_enron_by_day.txt
# Processed file: /content/data/235_enron_by_day.txt
# Processed file: /content/data/236_enron_by_day.txt
# Processed file: /content/data/237_enron_by_day.txt
# Processed file: /content/data/238_enron_by_day.txt
# Processed file: /content/data/239_enron_by_day.txt
# Processed file: /content/data/240_enron_by_day.txt
# Processed file: /content/data/241_enron_by_day.txt
# Processed file: /content/data/242_enron_by_day.txt
# Processed file: /content/data/243_enron_by_day.txt
# Processed file: /content/data/244_enron_by_day.txt
# Processed file: /content/data/245_enron_by_day.txt
# Processed file: /content/data/246_enron_by_day.txt
# Processed file: /content/data/247_enron_by_day.txt
# Processed file: /content/data/248_enron_by_day.txt
# Processed file: /content/data/249_enron_by_day.txt
# Processed file: /content/data/250_enron_by_day.txt
# Processed file: /content/data/251_enron_by_day.txt
# Processed file: /content/data/252_enron_by_day.txt
# Processed file: /content/data/253_enron_by_day.txt
# Processed file: /content/data/254_enron_by_day.txt
# Processed file: /content/data/255_enron_by_day.txt
# Processed file: /content/data/256_enron_by_day.txt
# Processed file: /content/data/257_enron_by_day.txt
# Processed file: /content/data/258_enron_by_day.txt
# Processed file: /content/data/259_enron_by_day.txt
# Processed file: /content/data/260_enron_by_day.txt
# Processed file: /content/data/261_enron_by_day.txt
# Processed file: /content/data/262_enron_by_day.txt
# Processed file: /content/data/263_enron_by_day.txt
# Processed file: /content/data/264_enron_by_day.txt
# Processed file: /content/data/265_enron_by_day.txt
# Processed file: /content/data/266_enron_by_day.txt
# Processed file: /content/data/267_enron_by_day.txt
# Processed file: /content/data/268_enron_by_day.txt
# Processed file: /content/data/269_enron_by_day.txt
# Processed file: /content/data/270_enron_by_day.txt
# Processed file: /content/data/271_enron_by_day.txt
# Processed file: /content/data/272_enron_by_day.txt
# Processed file: /content/data/273_enron_by_day.txt
# Processed file: /content/data/274_enron_by_day.txt
# Processed file: /content/data/275_enron_by_day.txt
# Processed file: /content/data/276_enron_by_day.txt
# Processed file: /content/data/277_enron_by_day.txt
# Processed file: /content/data/278_enron_by_day.txt
# Processed file: /content/data/279_enron_by_day.txt
# Processed file: /content/data/280_enron_by_day.txt
# Processed file: /content/data/281_enron_by_day.txt
# Processed file: /content/data/282_enron_by_day.txt
# Processed file: /content/data/283_enron_by_day.txt
# Processed file: /content/data/284_enron_by_day.txt
# Processed file: /content/data/285_enron_by_day.txt
# Processed file: /content/data/286_enron_by_day.txt
# Processed file: /content/data/287_enron_by_day.txt
# Processed file: /content/data/288_enron_by_day.txt
# Processed file: /content/data/289_enron_by_day.txt
# Processed file: /content/data/290_enron_by_day.txt
# Processed file: /content/data/291_enron_by_day.txt
# Processed file: /content/data/292_enron_by_day.txt
# Processed file: /content/data/293_enron_by_day.txt
# Processed file: /content/data/294_enron_by_day.txt
# Processed file: /content/data/295_enron_by_day.txt
# Processed file: /content/data/296_enron_by_day.txt
# Processed file: /content/data/297_enron_by_day.txt
# Processed file: /content/data/298_enron_by_day.txt
# Processed file: /content/data/299_enron_by_day.txt
# Processed file: /content/data/300_enron_by_day.txt
# Processed file: /content/data/301_enron_by_day.txt
# Processed file: /content/data/302_enron_by_day.txt
# Processed file: /content/data/303_enron_by_day.txt
# Processed file: /content/data/304_enron_by_day.txt
# Processed file: /content/data/305_enron_by_day.txt
# Processed file: /content/data/306_enron_by_day.txt
# Processed file: /content/data/307_enron_by_day.txt
# Processed file: /content/data/308_enron_by_day.txt
# Processed file: /content/data/309_enron_by_day.txt
# Processed file: /content/data/310_enron_by_day.txt
# Processed file: /content/data/311_enron_by_day.txt
# Processed file: /content/data/312_enron_by_day.txt
# Processed file: /content/data/313_enron_by_day.txt
# Processed file: /content/data/314_enron_by_day.txt
# Processed file: /content/data/315_enron_by_day.txt
# Processed file: /content/data/316_enron_by_day.txt
# Processed file: /content/data/317_enron_by_day.txt
# Processed file: /content/data/318_enron_by_day.txt
# Processed file: /content/data/319_enron_by_day.txt
# Processed file: /content/data/320_enron_by_day.txt
# Processed file: /content/data/321_enron_by_day.txt
# Processed file: /content/data/322_enron_by_day.txt
# Processed file: /content/data/323_enron_by_day.txt
# Processed file: /content/data/324_enron_by_day.txt
# Processed file: /content/data/325_enron_by_day.txt
# Processed file: /content/data/326_enron_by_day.txt
# Processed file: /content/data/327_enron_by_day.txt
# Processed file: /content/data/328_enron_by_day.txt
# Processed file: /content/data/329_enron_by_day.txt
# Processed file: /content/data/330_enron_by_day.txt
# Processed file: /content/data/331_enron_by_day.txt
# Processed file: /content/data/332_enron_by_day.txt
# Processed file: /content/data/333_enron_by_day.txt
# Processed file: /content/data/334_enron_by_day.txt
# Processed file: /content/data/335_enron_by_day.txt
# Processed file: /content/data/336_enron_by_day.txt
# Processed file: /content/data/337_enron_by_day.txt
# Processed file: /content/data/338_enron_by_day.txt
# Processed file: /content/data/339_enron_by_day.txt
# Processed file: /content/data/340_enron_by_day.txt
# Processed file: /content/data/341_enron_by_day.txt
# Processed file: /content/data/342_enron_by_day.txt
# Processed file: /content/data/343_enron_by_day.txt
# Processed file: /content/data/344_enron_by_day.txt
# Processed file: /content/data/345_enron_by_day.txt
# Processed file: /content/data/346_enron_by_day.txt
# Processed file: /content/data/347_enron_by_day.txt
# Processed file: /content/data/348_enron_by_day.txt
# Processed file: /content/data/349_enron_by_day.txt
# Processed file: /content/data/350_enron_by_day.txt
# Processed file: /content/data/351_enron_by_day.txt
# Processed file: /content/data/352_enron_by_day.txt
# Processed file: /content/data/353_enron_by_day.txt
# Processed file: /content/data/354_enron_by_day.txt
# Processed file: /content/data/355_enron_by_day.txt
# Processed file: /content/data/356_enron_by_day.txt
# Processed file: /content/data/357_enron_by_day.txt
# Processed file: /content/data/358_enron_by_day.txt
# Processed file: /content/data/359_enron_by_day.txt
# Processed file: /content/data/360_enron_by_day.txt
# Processed file: /content/data/361_enron_by_day.txt
# Processed file: /content/data/362_enron_by_day.txt
# Processed file: /content/data/363_enron_by_day.txt
# Processed file: /content/data/364_enron_by_day.txt
# Processed file: /content/data/365_enron_by_day.txt
# Processed file: /content/data/366_enron_by_day.txt
# Processed file: /content/data/367_enron_by_day.txt
# Processed file: /content/data/368_enron_by_day.txt
# Processed file: /content/data/369_enron_by_day.txt
# Processed file: /content/data/370_enron_by_day.txt
# Processed file: /content/data/371_enron_by_day.txt
# Processed file: /content/data/372_enron_by_day.txt
# Processed file: /content/data/373_enron_by_day.txt
# Processed file: /content/data/374_enron_by_day.txt
# Processed file: /content/data/375_enron_by_day.txt
# Processed file: /content/data/376_enron_by_day.txt
# Processed file: /content/data/377_enron_by_day.txt
# Processed file: /content/data/378_enron_by_day.txt
# Processed file: /content/data/379_enron_by_day.txt
# Processed file: /content/data/380_enron_by_day.txt
# Processed file: /content/data/381_enron_by_day.txt
# Processed file: /content/data/382_enron_by_day.txt
# Processed file: /content/data/383_enron_by_day.txt
# Processed file: /content/data/384_enron_by_day.txt
# Processed file: /content/data/385_enron_by_day.txt
# Processed file: /content/data/386_enron_by_day.txt
# Processed file: /content/data/387_enron_by_day.txt
# Processed file: /content/data/388_enron_by_day.txt
# Processed file: /content/data/389_enron_by_day.txt
# Processed file: /content/data/390_enron_by_day.txt
# Processed file: /content/data/391_enron_by_day.txt
# Processed file: /content/data/392_enron_by_day.txt
# Processed file: /content/data/393_enron_by_day.txt
# Processed file: /content/data/394_enron_by_day.txt
# Processed file: /content/data/395_enron_by_day.txt
# Processed file: /content/data/396_enron_by_day.txt
# Processed file: /content/data/397_enron_by_day.txt
# Processed file: /content/data/398_enron_by_day.txt
# Processed file: /content/data/399_enron_by_day.txt
# Processed file: /content/data/400_enron_by_day.txt
# Processed file: /content/data/401_enron_by_day.txt
# Processed file: /content/data/402_enron_by_day.txt
# Processed file: /content/data/403_enron_by_day.txt
# Processed file: /content/data/404_enron_by_day.txt
# Processed file: /content/data/405_enron_by_day.txt
# Processed file: /content/data/406_enron_by_day.txt
# Processed file: /content/data/407_enron_by_day.txt
# Processed file: /content/data/408_enron_by_day.txt
# Processed file: /content/data/409_enron_by_day.txt
# Processed file: /content/data/410_enron_by_day.txt
# Processed file: /content/data/411_enron_by_day.txt
# Processed file: /content/data/412_enron_by_day.txt
# Processed file: /content/data/413_enron_by_day.txt
# Processed file: /content/data/414_enron_by_day.txt
# Processed file: /content/data/415_enron_by_day.txt
# Processed file: /content/data/416_enron_by_day.txt
# Processed file: /content/data/417_enron_by_day.txt
# Processed file: /content/data/418_enron_by_day.txt
# Processed file: /content/data/419_enron_by_day.txt
# Processed file: /content/data/420_enron_by_day.txt
# Processed file: /content/data/421_enron_by_day.txt
# Processed file: /content/data/422_enron_by_day.txt
# Processed file: /content/data/423_enron_by_day.txt
# Processed file: /content/data/424_enron_by_day.txt
# Processed file: /content/data/425_enron_by_day.txt
# Processed file: /content/data/426_enron_by_day.txt
# Processed file: /content/data/427_enron_by_day.txt
# Processed file: /content/data/428_enron_by_day.txt
# Processed file: /content/data/429_enron_by_day.txt
# Processed file: /content/data/430_enron_by_day.txt
# Processed file: /content/data/431_enron_by_day.txt
# Processed file: /content/data/432_enron_by_day.txt
# Processed file: /content/data/433_enron_by_day.txt
# Processed file: /content/data/434_enron_by_day.txt
# Processed file: /content/data/435_enron_by_day.txt
# Processed file: /content/data/436_enron_by_day.txt
# Processed file: /content/data/437_enron_by_day.txt
# Processed file: /content/data/438_enron_by_day.txt
# Processed file: /content/data/439_enron_by_day.txt
# Processed file: /content/data/440_enron_by_day.txt
# Processed file: /content/data/441_enron_by_day.txt
# Processed file: /content/data/442_enron_by_day.txt
# Processed file: /content/data/443_enron_by_day.txt
# Processed file: /content/data/444_enron_by_day.txt
# Processed file: /content/data/445_enron_by_day.txt
# Processed file: /content/data/446_enron_by_day.txt
# Processed file: /content/data/447_enron_by_day.txt
# Processed file: /content/data/448_enron_by_day.txt
# Processed file: /content/data/449_enron_by_day.txt
# Processed file: /content/data/450_enron_by_day.txt
# Processed file: /content/data/451_enron_by_day.txt
# Processed file: /content/data/452_enron_by_day.txt
# Processed file: /content/data/453_enron_by_day.txt
# Processed file: /content/data/454_enron_by_day.txt
# Processed file: /content/data/455_enron_by_day.txt
# Processed file: /content/data/456_enron_by_day.txt
# Processed file: /content/data/457_enron_by_day.txt
# Processed file: /content/data/458_enron_by_day.txt
# Processed file: /content/data/459_enron_by_day.txt
# Processed file: /content/data/460_enron_by_day.txt
# Processed file: /content/data/461_enron_by_day.txt
# Processed file: /content/data/462_enron_by_day.txt
# Processed file: /content/data/463_enron_by_day.txt
# Processed file: /content/data/464_enron_by_day.txt
# Processed file: /content/data/465_enron_by_day.txt
# Processed file: /content/data/466_enron_by_day.txt
# Processed file: /content/data/467_enron_by_day.txt
# Processed file: /content/data/468_enron_by_day.txt
# Processed file: /content/data/469_enron_by_day.txt
# Processed file: /content/data/470_enron_by_day.txt
# Processed file: /content/data/471_enron_by_day.txt
# Processed file: /content/data/472_enron_by_day.txt
# Processed file: /content/data/473_enron_by_day.txt
# Processed file: /content/data/474_enron_by_day.txt
# Processed file: /content/data/475_enron_by_day.txt
# Processed file: /content/data/476_enron_by_day.txt
# Processed file: /content/data/477_enron_by_day.txt
# Processed file: /content/data/478_enron_by_day.txt
# Processed file: /content/data/479_enron_by_day.txt
# Processed file: /content/data/480_enron_by_day.txt
# Processed file: /content/data/481_enron_by_day.txt
# Processed file: /content/data/482_enron_by_day.txt
# Processed file: /content/data/483_enron_by_day.txt
# Processed file: /content/data/484_enron_by_day.txt
# Processed file: /content/data/485_enron_by_day.txt
# Processed file: /content/data/486_enron_by_day.txt
# Processed file: /content/data/487_enron_by_day.txt
# Processed file: /content/data/488_enron_by_day.txt
# Processed file: /content/data/489_enron_by_day.txt
# Processed file: /content/data/490_enron_by_day.txt
# Processed file: /content/data/491_enron_by_day.txt
# Processed file: /content/data/492_enron_by_day.txt
# Processed file: /content/data/493_enron_by_day.txt
# Processed file: /content/data/494_enron_by_day.txt
# Processed file: /content/data/495_enron_by_day.txt
# Processed file: /content/data/496_enron_by_day.txt
# Processed file: /content/data/497_enron_by_day.txt
# Processed file: /content/data/498_enron_by_day.txt
# Processed file: /content/data/499_enron_by_day.txt
# Processed file: /content/data/500_enron_by_day.txt
# Processed file: /content/data/501_enron_by_day.txt
# Processed file: /content/data/502_enron_by_day.txt
# Processed file: /content/data/503_enron_by_day.txt
# Processed file: /content/data/504_enron_by_day.txt
# Processed file: /content/data/505_enron_by_day.txt
# Processed file: /content/data/506_enron_by_day.txt
# Processed file: /content/data/507_enron_by_day.txt
# Processed file: /content/data/508_enron_by_day.txt
# Processed file: /content/data/509_enron_by_day.txt
# Processed file: /content/data/510_enron_by_day.txt
# Processed file: /content/data/511_enron_by_day.txt
# Processed file: /content/data/512_enron_by_day.txt
# Processed file: /content/data/513_enron_by_day.txt
# Processed file: /content/data/514_enron_by_day.txt
# Processed file: /content/data/515_enron_by_day.txt
# Processed file: /content/data/516_enron_by_day.txt
# Processed file: /content/data/517_enron_by_day.txt
# Processed file: /content/data/518_enron_by_day.txt
# Processed file: /content/data/519_enron_by_day.txt
# Processed file: /content/data/520_enron_by_day.txt
# Processed file: /content/data/521_enron_by_day.txt
# Processed file: /content/data/522_enron_by_day.txt
# Processed file: /content/data/523_enron_by_day.txt
# Processed file: /content/data/524_enron_by_day.txt
# Processed file: /content/data/525_enron_by_day.txt
# Processed file: /content/data/526_enron_by_day.txt
# Processed file: /content/data/527_enron_by_day.txt
# Processed file: /content/data/528_enron_by_day.txt
# Processed file: /content/data/529_enron_by_day.txt
# Processed file: /content/data/530_enron_by_day.txt
# Processed file: /content/data/531_enron_by_day.txt
# Processed file: /content/data/532_enron_by_day.txt
# Processed file: /content/data/533_enron_by_day.txt
# Processed file: /content/data/534_enron_by_day.txt
# Processed file: /content/data/535_enron_by_day.txt
# Processed file: /content/data/536_enron_by_day.txt
# Processed file: /content/data/537_enron_by_day.txt
# Processed file: /content/data/538_enron_by_day.txt
# Processed file: /content/data/539_enron_by_day.txt
# Processed file: /content/data/540_enron_by_day.txt
# Processed file: /content/data/541_enron_by_day.txt
# Processed file: /content/data/542_enron_by_day.txt
# Processed file: /content/data/543_enron_by_day.txt
# Processed file: /content/data/544_enron_by_day.txt
# Processed file: /content/data/545_enron_by_day.txt
# Processed file: /content/data/546_enron_by_day.txt
# Processed file: /content/data/547_enron_by_day.txt
# Processed file: /content/data/548_enron_by_day.txt
# Processed file: /content/data/549_enron_by_day.txt
# Processed file: /content/data/550_enron_by_day.txt
# Processed file: /content/data/551_enron_by_day.txt
# Processed file: /content/data/552_enron_by_day.txt
# Processed file: /content/data/553_enron_by_day.txt
# Processed file: /content/data/554_enron_by_day.txt
# Processed file: /content/data/555_enron_by_day.txt
# Processed file: /content/data/556_enron_by_day.txt
# Processed file: /content/data/557_enron_by_day.txt
# Processed file: /content/data/558_enron_by_day.txt
# Processed file: /content/data/559_enron_by_day.txt
# Processed file: /content/data/560_enron_by_day.txt
# Processed file: /content/data/561_enron_by_day.txt
# Processed file: /content/data/562_enron_by_day.txt
# Processed file: /content/data/563_enron_by_day.txt
# Processed file: /content/data/564_enron_by_day.txt
# Processed file: /content/data/565_enron_by_day.txt
# Processed file: /content/data/566_enron_by_day.txt
# Processed file: /content/data/567_enron_by_day.txt
# Processed file: /content/data/568_enron_by_day.txt
# Processed file: /content/data/569_enron_by_day.txt
# Processed file: /content/data/570_enron_by_day.txt
# Processed file: /content/data/571_enron_by_day.txt
# Processed file: /content/data/572_enron_by_day.txt
# Processed file: /content/data/573_enron_by_day.txt
# Processed file: /content/data/574_enron_by_day.txt
# Processed file: /content/data/575_enron_by_day.txt
# Processed file: /content/data/576_enron_by_day.txt
# Processed file: /content/data/577_enron_by_day.txt
# Processed file: /content/data/578_enron_by_day.txt
# Processed file: /content/data/579_enron_by_day.txt
# Processed file: /content/data/580_enron_by_day.txt
# Processed file: /content/data/581_enron_by_day.txt
# Processed file: /content/data/582_enron_by_day.txt
# Processed file: /content/data/583_enron_by_day.txt
# Processed file: /content/data/584_enron_by_day.txt
# Processed file: /content/data/585_enron_by_day.txt
# Processed file: /content/data/586_enron_by_day.txt
# Processed file: /content/data/587_enron_by_day.txt
# Processed file: /content/data/588_enron_by_day.txt
# Processed file: /content/data/589_enron_by_day.txt
# Processed file: /content/data/590_enron_by_day.txt
# Processed file: /content/data/591_enron_by_day.txt
# Processed file: /content/data/592_enron_by_day.txt
# Processed file: /content/data/593_enron_by_day.txt
# Processed file: /content/data/594_enron_by_day.txt
# Processed file: /content/data/595_enron_by_day.txt
# Processed file: /content/data/596_enron_by_day.txt
# Processed file: /content/data/597_enron_by_day.txt
# Processed file: /content/data/598_enron_by_day.txt
# Processed file: /content/data/599_enron_by_day.txt
# Processed file: /content/data/600_enron_by_day.txt
# Processed file: /content/data/601_enron_by_day.txt
# Processed file: /content/data/602_enron_by_day.txt
# Processed file: /content/data/603_enron_by_day.txt
# Processed file: /content/data/604_enron_by_day.txt
# Processed file: /content/data/605_enron_by_day.txt
# Processed file: /content/data/606_enron_by_day.txt
# Processed file: /content/data/607_enron_by_day.txt
# Processed file: /content/data/608_enron_by_day.txt
# Processed file: /content/data/609_enron_by_day.txt
# Processed file: /content/data/610_enron_by_day.txt
# Processed file: /content/data/611_enron_by_day.txt
# Processed file: /content/data/612_enron_by_day.txt
# Processed file: /content/data/613_enron_by_day.txt
# Processed file: /content/data/614_enron_by_day.txt
# Processed file: /content/data/615_enron_by_day.txt
# Processed file: /content/data/616_enron_by_day.txt
# Processed file: /content/data/617_enron_by_day.txt
# Processed file: /content/data/618_enron_by_day.txt
# Processed file: /content/data/619_enron_by_day.txt
# Processed file: /content/data/620_enron_by_day.txt
# Processed file: /content/data/621_enron_by_day.txt
# Processed file: /content/data/622_enron_by_day.txt
# Processed file: /content/data/623_enron_by_day.txt
# Processed file: /content/data/624_enron_by_day.txt
# Processed file: /content/data/625_enron_by_day.txt
# Processed file: /content/data/626_enron_by_day.txt
# Processed file: /content/data/627_enron_by_day.txt
# Processed file: /content/data/628_enron_by_day.txt
# Processed file: /content/data/629_enron_by_day.txt
# Processed file: /content/data/630_enron_by_day.txt
# Processed file: /content/data/631_enron_by_day.txt
# Processed file: /content/data/632_enron_by_day.txt
# Processed file: /content/data/633_enron_by_day.txt
# Processed file: /content/data/634_enron_by_day.txt
# Processed file: /content/data/635_enron_by_day.txt
# Processed file: /content/data/636_enron_by_day.txt
# Processed file: /content/data/637_enron_by_day.txt
# Processed file: /content/data/638_enron_by_day.txt
# Processed file: /content/data/639_enron_by_day.txt
# Processed file: /content/data/640_enron_by_day.txt
# Processed file: /content/data/641_enron_by_day.txt
# Processed file: /content/data/642_enron_by_day.txt
# Processed file: /content/data/643_enron_by_day.txt
# Processed file: /content/data/644_enron_by_day.txt
# Processed file: /content/data/645_enron_by_day.txt
# Processed file: /content/data/646_enron_by_day.txt
# Processed file: /content/data/647_enron_by_day.txt
# Processed file: /content/data/648_enron_by_day.txt
# Processed file: /content/data/649_enron_by_day.txt
# Processed file: /content/data/650_enron_by_day.txt
# Processed file: /content/data/651_enron_by_day.txt
# Processed file: /content/data/652_enron_by_day.txt
# Processed file: /content/data/653_enron_by_day.txt
# Processed file: /content/data/654_enron_by_day.txt
# Processed file: /content/data/655_enron_by_day.txt
# Processed file: /content/data/656_enron_by_day.txt
# Processed file: /content/data/657_enron_by_day.txt
# Processed file: /content/data/658_enron_by_day.txt
# Processed file: /content/data/659_enron_by_day.txt
# Processed file: /content/data/660_enron_by_day.txt
# Processed file: /content/data/661_enron_by_day.txt
# Processed file: /content/data/662_enron_by_day.txt
# Processed file: /content/data/663_enron_by_day.txt
# Processed file: /content/data/664_enron_by_day.txt
# Processed file: /content/data/665_enron_by_day.txt
# Processed file: /content/data/666_enron_by_day.txt
# Processed file: /content/data/667_enron_by_day.txt
# Processed file: /content/data/668_enron_by_day.txt
# Processed file: /content/data/669_enron_by_day.txt
# Processed file: /content/data/670_enron_by_day.txt
# Processed file: /content/data/671_enron_by_day.txt
# Processed file: /content/data/672_enron_by_day.txt
# Processed file: /content/data/673_enron_by_day.txt
# Processed file: /content/data/674_enron_by_day.txt
# Processed file: /content/data/675_enron_by_day.txt
# Processed file: /content/data/676_enron_by_day.txt
# Processed file: /content/data/677_enron_by_day.txt
# Processed file: /content/data/678_enron_by_day.txt
# Processed file: /content/data/679_enron_by_day.txt
# Processed file: /content/data/680_enron_by_day.txt
# Processed file: /content/data/681_enron_by_day.txt
# Processed file: /content/data/682_enron_by_day.txt
# Processed file: /content/data/683_enron_by_day.txt
# Processed file: /content/data/684_enron_by_day.txt
# Processed file: /content/data/685_enron_by_day.txt
# Processed file: /content/data/686_enron_by_day.txt
# Processed file: /content/data/687_enron_by_day.txt
# Processed file: /content/data/688_enron_by_day.txt
# Processed file: /content/data/689_enron_by_day.txt
# Processed file: /content/data/690_enron_by_day.txt
# Processed file: /content/data/691_enron_by_day.txt
# Processed file: /content/data/692_enron_by_day.txt
# Processed file: /content/data/693_enron_by_day.txt
# Processed file: /content/data/694_enron_by_day.txt
# Processed file: /content/data/695_enron_by_day.txt
# Processed file: /content/data/696_enron_by_day.txt
# Processed file: /content/data/697_enron_by_day.txt
# Processed file: /content/data/698_enron_by_day.txt
# Processed file: /content/data/699_enron_by_day.txt
# Processed file: /content/data/700_enron_by_day.txt
# Processed file: /content/data/701_enron_by_day.txt
# Processed file: /content/data/702_enron_by_day.txt
# Processed file: /content/data/703_enron_by_day.txt
# Processed file: /content/data/704_enron_by_day.txt
# Processed file: /content/data/705_enron_by_day.txt
# Processed file: /content/data/706_enron_by_day.txt
# Processed file: /content/data/707_enron_by_day.txt
# Processed file: /content/data/708_enron_by_day.txt
# Processed file: /content/data/709_enron_by_day.txt
# Processed file: /content/data/710_enron_by_day.txt
# Processed file: /content/data/711_enron_by_day.txt
# Processed file: /content/data/712_enron_by_day.txt
# Processed file: /content/data/713_enron_by_day.txt
# Processed file: /content/data/714_enron_by_day.txt
# Processed file: /content/data/715_enron_by_day.txt
# Processed file: /content/data/716_enron_by_day.txt
# Processed file: /content/data/717_enron_by_day.txt
# Processed file: /content/data/718_enron_by_day.txt
# Processed file: /content/data/719_enron_by_day.txt
# Processed file: /content/data/720_enron_by_day.txt
# Processed file: /content/data/721_enron_by_day.txt
# Processed file: /content/data/722_enron_by_day.txt
# Processed file: /content/data/723_enron_by_day.txt
# Processed file: /content/data/724_enron_by_day.txt
# Processed file: /content/data/725_enron_by_day.txt
# Processed file: /content/data/726_enron_by_day.txt
# Processed file: /content/data/727_enron_by_day.txt
# Processed file: /content/data/728_enron_by_day.txt
# Processed file: /content/data/729_enron_by_day.txt
# Processed file: /content/data/730_enron_by_day.txt
# Processed file: /content/data/731_enron_by_day.txt
# Processed file: /content/data/732_enron_by_day.txt
# Processed file: /content/data/733_enron_by_day.txt
# Processed file: /content/data/734_enron_by_day.txt
# Processed file: /content/data/735_enron_by_day.txt
# Processed file: /content/data/736_enron_by_day.txt
# Processed file: /content/data/737_enron_by_day.txt
# Processed file: /content/data/738_enron_by_day.txt
# Processed file: /content/data/739_enron_by_day.txt
# Processed file: /content/data/740_enron_by_day.txt
# Processed file: /content/data/741_enron_by_day.txt
# Processed file: /content/data/742_enron_by_day.txt
# Processed file: /content/data/743_enron_by_day.txt
# Processed file: /content/data/744_enron_by_day.txt
# Processed file: /content/data/745_enron_by_day.txt
# Processed file: /content/data/746_enron_by_day.txt
# Processed file: /content/data/747_enron_by_day.txt
# Processed file: /content/data/748_enron_by_day.txt
# Processed file: /content/data/749_enron_by_day.txt
# Processed file: /content/data/750_enron_by_day.txt
# Processed file: /content/data/751_enron_by_day.txt
# Processed file: /content/data/752_enron_by_day.txt
# Processed file: /content/data/753_enron_by_day.txt
# Processed file: /content/data/754_enron_by_day.txt
# Processed file: /content/data/755_enron_by_day.txt
# Processed file: /content/data/756_enron_by_day.txt
# Processed file: /content/data/757_enron_by_day.txt
# Processed file: /content/data/758_enron_by_day.txt
# Processed file: /content/data/759_enron_by_day.txt
# Processed file: /content/data/760_enron_by_day.txt
# Processed file: /content/data/761_enron_by_day.txt
# Processed file: /content/data/762_enron_by_day.txt
# Processed file: /content/data/763_enron_by_day.txt
# Processed file: /content/data/764_enron_by_day.txt
# Processed file: /content/data/765_enron_by_day.txt
# Processed file: /content/data/766_enron_by_day.txt
# Processed file: /content/data/767_enron_by_day.txt
# Processed file: /content/data/768_enron_by_day.txt
# Processed file: /content/data/769_enron_by_day.txt
# Processed file: /content/data/770_enron_by_day.txt
# Processed file: /content/data/771_enron_by_day.txt
# Processed file: /content/data/772_enron_by_day.txt
# 81 50  :  0.17543839772251535
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a5d193e24185> in <module>()
#     101         print(key, ' : ', val)
#     102         for d in key:
# --> 103             if int(d) == 1:
#     104                 binary_list.append(val)
#     105             else:
#
# ValueError: invalid literal for int() with base 10: ' '
