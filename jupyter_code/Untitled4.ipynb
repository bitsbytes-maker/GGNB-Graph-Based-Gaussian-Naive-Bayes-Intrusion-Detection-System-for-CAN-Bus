# %%
# !unzip /content/replay_and_attackfree_combined.zip
# Out:
# Archive:  /content/replay_and_attackfree_combined.zip
#   inflating: replay_and_attackfree_combined.txt

# %%
file_ = open('/content/replay_and_attackfree_combined(1).txt', 'r')
fileW = open('replayandAttackkfreCombined.txt','w')
i = 0
while True: 
  
    # Get next line from file 
    line = file_.readline() 
  
    # if line is empty 
    # end of file is reached 
    if not line: 
        break
    list1 = list(line.split())
    if len(list1) != 0:
      fileW.write(line)
    
    

  
    
    i = i+1


fileW.close()
