# %%
import numpy as np
d = np.array([[ 5587  ,  88],
 [   30 ,12623]])
 
s =  np.array([[10479,1337],
 [   25, 11267]])
 
f = np.array([[6568, 141],
               [0, 12485]])
r = np.array([[659, 0],
               [10,527]])

sum_mat = d+s+f+r

print("Overall Matrix")
print(sum_mat)
print("All the test data = "+ str(np.sum(sum_mat)))
print(np.trace(sum_mat)/np.sum(sum_mat))
# Out:
# Overall Matrix
# [[23293  1566]
#  [   65 36902]]
# All the test data = 61826
# 0.973619512826319
