# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import naive_bayes as nb
from sklearn.metrics import accuracy_score
import pandas
import time
import numpy as np
m  = []
d = []
s = []
f = []
r = []

def com(filename, number, attackName):

# load dataset
  dataframe = pandas.read_table(filename)
  data1 = dataframe.drop("No.", axis=1)
  data2 = data1.drop("State", axis =1)
  dataset = dataframe.values



# split into input (X) and output (Y) variables

  l = number  
#l = 18565 + 659
  X = dataset[0:l,1:]
# Y = dataset[100:200, 1:10]
# print(X)
# print(X.shape)
  labels = []
  for i in range (0,l):
    if X[i][9] == 'T':
      labels.append(0)
    else:
      labels.append(1)

  features = X[0:l,0:9]

# print(len(features))
# print(len(features[0]))
# print(features)
# print(labels)





# Split our data
  train, test, train_labels, test_labels = train_test_split(features,
                                                          labels,
                                                          test_size=0.33,
                                                          random_state=42)

# Initialize our classifier
  gnb = svm.SVC()

# Train our classifier
  time1 = time.time()
  model = gnb.fit(train, train_labels)
  time2 = time.time()
  if attackName == 'M':

    init = time.time()
    #print("M")
    preds = gnb.predict(test)
    #print(classification_report(test_labels, preds))
    
    m.append(time.time() - init)
  if attackName == 'D':

    init = time.time()
    #print("D")
    preds = gnb.predict(test)
    #print(classification_report(test_labels, preds))
    d.append(time.time() - init)

  
  if attackName == 'S':

    init = time.time()
    preds = gnb.predict(test)
    #print("S")
    #print(classification_report(test_labels, preds))
    s.append(time.time() - init)

  if attackName == 'F':

    init = time.time()
    preds = gnb.predict(test)
    #print("F")
    #print(classification_report(test_labels, preds))
    f.append(time.time() - init)

  
  if attackName == 'R':

    init = time.time()
    preds = gnb.predict(test)
    #print("R")
    #print(classification_report(test_labels, preds))
    r.append(time.time() - init)


for i in range (0,5):
  com('/content/completeallwithNode.txt',79854, "M")
  com('/content/complete_dos1.txt',18565+18328, "D")
  com('/content/complete_spoof1.txt',18565+23108, "S")
  com('/content/complete_fuuzy1.txt',18565+19194,"F")
  com('/content/complete_replay1.txt',18565+659,"R")


print("Mixed attack")
print(np.mean(m))
print("Dos attack")
print(np.mean(d))
print("Spoof attack")
print(np.mean(s))
print("Fuzzy attack")
print(np.mean(f))
print("Replay attack")
print(np.mean(r))
# print(preds)
# print("Mixed attack")
# init = time.time()
# com('/content/completeallwithNode.txt',79854)
# print(time.time() - init)


# print("Dos attack")
# init = time.time()
# com('/content/complete_dos1.txt',18565+18328)
# print(time.time() - init)


# print("Spoof attack")
# init = time.time()
# com('/content/complete_spoof1.txt',18565+23108)
# print(time.time() - init)

# print("Fuzzy attack")
# init = time.time()
# com('/content/complete_fuuzy1.txt',18565+19194)
# print(time.time() - init)

# print("Replay attack")
# init = time.time()
# com('/content/complete_replay1.txt',18565+659)
# print(time.time() - init)

# # Evaluate accuracy
# print(accuracy_score(test_labels, preds))
# Out:
# Mixed attack
# 2.3339227199554444
# Dos attack
# 0.06907114982604981
# Spoof attack
# 0.9520307540893554
# Fuzzy attack
# 0.08050212860107422
# Replay attack
# 0.00454559326171875

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import naive_bayes as nb
from sklearn.metrics import accuracy_score
import pandas
import time
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, GRU, Input
from keras.layers import Conv2D, MaxPooling2D, Conv1D,MaxPooling1D
from keras import backend as K
from keras.preprocessing.text import Tokenizer, hashing_trick
from keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
m  = []
d = []
s = []
f = []
r = []

def com(filename, number, attackName):

# load dataset
  dataframe = pandas.read_table(filename)
  data1 = dataframe.drop("No.", axis=1)
  data2 = data1.drop("State", axis =1)
  dataset = dataframe.values



# split into input (X) and output (Y) variables

  l = number  
#l = 18565 + 659
  X = dataset[0:l,1:]
# Y = dataset[100:200, 1:10]
# print(X)
# print(X.shape)
  labels = []
  for i in range (0,l):
    if X[i][9] == 'T':
      labels.append(0)
    else:
      labels.append(1)

  features = X[0:l,0:9]

# print(len(features))
# print(len(features[0]))
# print(features)
# print(labels)





# Split our data
 

# Initialize our classifier
  features = np.array(features,dtype='float64')
  labels = np.array(labels, dtype ='float64')

# min_max_scaler = MinMaxScaler()
# X = min_max_scaler.fit_transform(features)

  X_train, X_test, Y_train, Y_test = train_test_split(features, labels, test_size=0.33)

  model = Sequential([ Dense(32, activation='relu', input_shape=(9,)), Dense(32, activation='relu'), Dense(1, activation='sigmoid'),])
# compile the keras model
  model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
  time1 = time.time()
  model.fit( np.array(X_train),#.reshape((train_X.shape[0], train_X.shape[1],1)), 
           np.array(Y_train),
           epochs = 10, 
           batch_size=32, 
           verbose = 1
          #, validation_data=(np.array(X_test), np.array(Y_test))
           )
  time2 = time.time()
  #_, accuracy = model.evaluate(X_test, Y_test)
  #print('Accuracy: %.2f' % (accuracy*100))

  

  testy = Y_test
# accuracy: (tp + tn) / (p + n)



# Train our classifier
 
  if attackName == 'M':

    init = time.time()
    #print("M")
    yhat_classes = model.predict_classes(X_test, verbose=0)
    #print(classification_report(test_labels, preds))
    
    m.append(time.time() - init)
  if attackName == 'D':

    init = time.time()
    #print("D")
    yhat_classes = model.predict_classes(X_test, verbose=0)
    #print(classification_report(test_labels, preds))
    d.append(time.time() - init)

  
  if attackName == 'S':

    init = time.time()
    yhat_classes = model.predict_classes(X_test, verbose=0)
    #print("S")
    #print(classification_report(test_labels, preds))
    s.append(time.time() - init)

  if attackName == 'F':

    init = time.time()
    yhat_classes = model.predict_classes(X_test, verbose=0)
    #print("F")
    #print(classification_report(test_labels, preds))
    f.append(time.time() - init)

  
  if attackName == 'R':

    init = time.time()
    yhat_classes = model.predict_classes(X_test, verbose=0)
    #print("R")
    #print(classification_report(test_labels, preds))
    r.append(time.time() - init)


for i in range (0,5):
  com('/content/completeallwithNode.txt',79854, "M")
  com('/content/complete_dos1.txt',18565+18328, "D")
  com('/content/complete_spoof1.txt',18565+23108, "S")
  com('/content/complete_fuuzy1.txt',18565+19194,"F")
  com('/content/complete_replay1.txt',18565+659,"R")

file = open("output.txt",'w')

file.write("Mixed attack\n")
file.write(str(np.mean(m))+"\n")
file.write("Dos attack\n")
file.write(str(np.mean(d))+"\n")
file.write("Spoof attack\n")
file.write(str(np.mean(s))+"\n")
file.write("Fuzzy attack\n")
file.write(str(np.mean(f))+"\n")
file.write("Replay attack\n")
file.write(str(np.mean(r)))
file.write("skfjkj")
file.close()
# print(preds)
# print("Mixed attack")
# init = time.time()
# com('/content/completeallwithNode.txt',79854)
# print(time.time() - init)


# print("Dos attack")
# init = time.time()
# com('/content/complete_dos1.txt',18565+18328)
# print(time.time() - init)


# print("Spoof attack")
# init = time.time()
# com('/content/complete_spoof1.txt',18565+23108)
# print(time.time() - init)

# print("Fuzzy attack")
# init = time.time()
# com('/content/complete_fuuzy1.txt',18565+19194)
# print(time.time() - init)

# print("Replay attack")
# init = time.time()
# com('/content/complete_replay1.txt',18565+659)
# print(time.time() - init)

# # Evaluate accuracy
# print(accuracy_score(test_labels, preds))
# Out:
# Epoch 1/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.1939 - accuracy: 0.9583
# Epoch 2/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0857 - accuracy: 0.9812
# Epoch 3/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0854 - accuracy: 0.9817
# Epoch 4/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0844 - accuracy: 0.9819
# Epoch 5/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0830 - accuracy: 0.9820
# Epoch 6/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0823 - accuracy: 0.9821
# Epoch 7/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0822 - accuracy: 0.9822
# Epoch 8/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0815 - accuracy: 0.9821
# Epoch 9/10
# 1672/1672 [==============================] - 2s 1ms/step - loss: 0.0810 - accuracy: 0.9822
# Epoch 10/10
# ...
