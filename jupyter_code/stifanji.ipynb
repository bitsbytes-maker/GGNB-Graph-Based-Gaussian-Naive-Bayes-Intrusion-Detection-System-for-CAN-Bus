# %%
# !git clone https://github.com/stefanjf/Anomaly-Detection-in-Graphs.git
# Out:
# Cloning into 'Anomaly-Detection-in-Graphs'...
# remote: Enumerating objects: 840, done.
# remote: Total 840 (delta 0), reused 0 (delta 0), pack-reused 840
# Receiving objects: 100% (840/840), 26.69 MiB | 38.60 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
